# %% [markdown]
# # Idea
# - Get first timestamp
# - Resample Dataset to same timewindow
# - Merge?

# %%
DEVICE_SOURCE = "Xi_sensor_1"

TIME_WINDOW = "30s"

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import pickle

# %%
import sys
repo_base_path = Path("./../").resolve()
assert str(repo_base_path).endswith("csg_is"), f"{repo_base_path} is not a valid path to the CSG_IS repository" 

sys.path.append(str(repo_base_path))

from py_dataset import get_all_files_df
from py_dataset import read_in_files
from py_dataset import feature_plotting
from py_dataset import feature_selection
from py_dataset import net_feature_engineering
from py_dataset import entropy_feature_engineering
from py_dataset import sys_func

from py_dataset.classes import DataSource

# %%
feature_path = repo_base_path / "data_merg" /"top_260_features.pkl"

with open(feature_path, "rb") as f:
    SELECTED_FEATURES = pickle.load(f)

# %%
data_path = Path('/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/')
assert data_path.exists()

df = get_all_files_df.main(data_path)
df.head(1)
# Out:
# txt file found, will drop /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Heqing/device1/3_thetick_4h/collections.txt
# txt file found, will drop /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Heqing/device2/1_normal/note.txt
#                                            file_path
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...
# RangeIndex(start=0, stop=622, step=1)
# filetype
# csv    530
# zip     92
# Name: count, dtype: int64
#                                            file_path filetype  filesize_bytes
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...      csv           49419
# data_source
# SYS_data        92
# KERN_data       91
# FLS_data        91
# RES_data        91
# block_data      91
# network_data    91
# entropy_data    75
# Name: count, dtype: int64
#                                            file_path filetype  filesize_bytes  \
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...      csv           49419
#
#   researcher_name device_name     label data_source              file_name  \
# 0          Heqing     device1  1_normal  block_data  e4_5f_01_68_35_e6.csv
#
#            device
# 0  Heqing_device1

# %%
single_dev = df[df["device"] == DEVICE_SOURCE]
assert len(single_dev["device"].unique()) == 1
print(single_dev.shape)

df = single_dev
# Out:
# (61, 9)

# %% [markdown]
# ### Get First TimeStamp

# %%
def prepare_files(row, resample_time_window):
    if row["filetype"] != "csv" and row["filetype"] != "zip":
        return None

    min_t, max_t, df_t = read_in_files.get_all_timestamps(row['file_path'], row["filetype"],
                                            resample_time_window=resample_time_window)

    row["min_t"] = min_t
    row["max_t"] = max_t

    return row

rows = []
for k, row in df.iterrows():
    x = prepare_files(row, resample_time_window=None)

    rows.append(x)

df_timestamps = pd.DataFrame(rows)
# Out:
# ! Dropped rows in DataFrames: (1248,)
# timestamp   NaN
# Name: 1, dtype: float64
# timestamp   NaN
# Name: 3, dtype: float64
# timestamp   NaN
# Name: 5, dtype: float64
# timestamp   NaN
# Name: 7, dtype: float64
# timestamp   NaN
# Name: 9, dtype: float64
# timestamp   NaN
# Name: 11, dtype: float64
# timestamp   NaN
# Name: 13, dtype: float64
# timestamp   NaN
# Name: 15, dtype: float64
# timestamp   NaN
# Name: 17, dtype: float64
# timestamp   NaN
# Name: 19, dtype: float64
# timestamp   NaN
# Name: 21, dtype: float64
# timestamp   NaN
# Name: 23, dtype: float64
# timestamp   NaN
# Name: 25, dtype: float64
# timestamp   NaN
# Name: 27, dtype: float64
# timestamp   NaN
# Name: 29, dtype: float64
# timestamp   NaN
# Name: 31, dtype: float64
# timestamp   NaN
# Name: 33, dtype: float64
# timestamp   NaN
# Name: 35, dtype: float64
# timestamp   NaN
# Name: 37, dtype: float64
# timestamp   NaN
# Name: 39, dtype: float64
# timestamp   NaN
# Name: 41, dtype: float64
# timestamp   NaN
# Name: 43, dtype: float64
# timestamp   NaN
# Name: 45, dtype: float64
# timestamp   NaN
# Name: 47, dtype: float64
# timestamp   NaN
# Name: 49, dtype: float64
# timestamp   NaN
# Name: 51, dtype: float64
# timestamp   NaN
# Name: 53, dtype: float64
# timestamp   NaN
# Name: 55, dtype: float64
# timestamp   NaN
# Name: 57, dtype: float64
# timestamp   NaN
# Name: 59, dtype: float64
# timestamp   NaN
# Name: 61, dtype: float64
# timestamp   NaN
# Name: 63, dtype: float64
# timestamp   NaN
# Name: 65, dtype: float64
# timestamp   NaN
# Name: 67, dtype: float64
# timestamp   NaN
# Name: 69, dtype: float64
# timestamp   NaN
# Name: 71, dtype: float64
# timestamp   NaN
# Name: 73, dtype: float64
# timestamp   NaN
# Name: 75, dtype: float64
# timestamp   NaN
# Name: 77, dtype: float64
# timestamp   NaN
# Name: 79, dtype: float64
# timestamp   NaN
# Name: 81, dtype: float64
# timestamp   NaN
# Name: 83, dtype: float64
# timestamp   NaN
# Name: 85, dtype: float64
# timestamp   NaN
# Name: 87, dtype: float64
# timestamp   NaN
# Name: 89, dtype: float64
# timestamp   NaN
# Name: 91, dtype: float64
# timestamp   NaN
# Name: 93, dtype: float64
# timestamp   NaN
# Name: 95, dtype: float64
# timestamp   NaN
# Name: 97, dtype: float64
# timestamp   NaN
# Name: 99, dtype: float64
# timestamp   NaN
# Name: 101, dtype: float64
# timestamp   NaN
# Name: 103, dtype: float64
# timestamp   NaN
# Name: 105, dtype: float64
# timestamp   NaN
# Name: 107, dtype: float64
# timestamp   NaN
# Name: 109, dtype: float64
# timestamp   NaN
# Name: 111, dtype: float64
# timestamp   NaN
# Name: 113, dtype: float64
# timestamp   NaN
# Name: 115, dtype: float64
# timestamp   NaN
# Name: 117, dtype: float64
# timestamp   NaN
# Name: 119, dtype: float64
# timestamp   NaN
# Name: 121, dtype: float64
# timestamp   NaN
# Name: 123, dtype: float64
# timestamp   NaN
# Name: 125, dtype: float64
# timestamp   NaN
# Name: 127, dtype: float64
# timestamp   NaN
# Name: 129, dtype: float64
# timestamp   NaN
# Name: 131, dtype: float64
# timestamp   NaN
# Name: 133, dtype: float64
# timestamp   NaN
# Name: 135, dtype: float64
# timestamp   NaN
# Name: 137, dtype: float64
# timestamp   NaN
# Name: 139, dtype: float64
# timestamp   NaN
# Name: 141, dtype: float64
# timestamp   NaN
# Name: 143, dtype: float64
# timestamp   NaN
# Name: 145, dtype: float64
# timestamp   NaN
# Name: 147, dtype: float64
# timestamp   NaN
# Name: 149, dtype: float64
# timestamp   NaN
# Name: 151, dtype: float64
# timestamp   NaN
# Name: 153, dtype: float64
# timestamp   NaN
# Name: 155, dtype: float64
# timestamp   NaN
# Name: 157, dtype: float64
# timestamp   NaN
# Name: 159, dtype: float64
# timestamp   NaN
# Name: 161, dtype: float64
# timestamp   NaN
# Name: 163, dtype: float64
# timestamp   NaN
# Name: 165, dtype: float64
# timestamp   NaN
# Name: 167, dtype: float64
# timestamp   NaN
# Name: 169, dtype: float64
# timestamp   NaN
# Name: 171, dtype: float64
# timestamp   NaN
# Name: 173, dtype: float64
# timestamp   NaN
# Name: 175, dtype: float64
# timestamp   NaN
# Name: 177, dtype: float64
# timestamp   NaN
# Name: 179, dtype: float64
# timestamp   NaN
# Name: 181, dtype: float64
# timestamp   NaN
# Name: 183, dtype: float64
# timestamp   NaN
# Name: 185, dtype: float64
# timestamp   NaN
# Name: 187, dtype: float64
# timestamp   NaN
# Name: 189, dtype: float64
# timestamp   NaN
# Name: 191, dtype: float64
# timestamp   NaN
# Name: 193, dtype: float64
# timestamp   NaN
# Name: 195, dtype: float64
# timestamp   NaN
# Name: 197, dtype: float64
# timestamp   NaN
# Name: 199, dtype: float64
# timestamp   NaN
# Name: 201, dtype: float64
# timestamp   NaN
# Name: 203, dtype: float64
# timestamp   NaN
# Name: 205, dtype: float64
# timestamp   NaN
# Name: 207, dtype: float64
# timestamp   NaN
# Name: 209, dtype: float64
# timestamp   NaN
# Name: 211, dtype: float64
# timestamp   NaN
# Name: 213, dtype: float64
# timestamp   NaN
# Name: 215, dtype: float64
# timestamp   NaN
# Name: 217, dtype: float64
# timestamp   NaN
# Name: 219, dtype: float64
# timestamp   NaN
# Name: 221, dtype: float64
# timestamp   NaN
# Name: 223, dtype: float64
# timestamp   NaN
# Name: 225, dtype: float64
# timestamp   NaN
# Name: 227, dtype: float64
# timestamp   NaN
# Name: 229, dtype: float64
# timestamp   NaN
# Name: 231, dtype: float64
# timestamp   NaN
# Name: 233, dtype: float64
# timestamp   NaN
# Name: 235, dtype: float64
# timestamp   NaN
# Name: 237, dtype: float64
# timestamp   NaN
# Name: 239, dtype: float64
# timestamp   NaN
# Name: 241, dtype: float64
# timestamp   NaN
# Name: 243, dtype: float64
# timestamp   NaN
# Name: 245, dtype: float64
# timestamp   NaN
# Name: 247, dtype: float64
# timestamp   NaN
# Name: 249, dtype: float64
# timestamp   NaN
# Name: 251, dtype: float64
# timestamp   NaN
# Name: 253, dtype: float64
# timestamp   NaN
# Name: 255, dtype: float64
# timestamp   NaN
# Name: 257, dtype: float64
# timestamp   NaN
# Name: 259, dtype: float64
# timestamp   NaN
# Name: 261, dtype: float64
# timestamp   NaN
# Name: 263, dtype: float64
# timestamp   NaN
# Name: 265, dtype: float64
# timestamp   NaN
# Name: 267, dtype: float64
# timestamp   NaN
# Name: 269, dtype: float64
# timestamp   NaN
# Name: 271, dtype: float64
# timestamp   NaN
# Name: 273, dtype: float64
# timestamp   NaN
# Name: 275, dtype: float64
# timestamp   NaN
# Name: 277, dtype: float64
# timestamp   NaN
# Name: 279, dtype: float64
# timestamp   NaN
# Name: 281, dtype: float64
# timestamp   NaN
# Name: 283, dtype: float64
# timestamp   NaN
# Name: 285, dtype: float64
# timestamp   NaN
# Name: 287, dtype: float64
# timestamp   NaN
# Name: 289, dtype: float64
# timestamp   NaN
# Name: 291, dtype: float64
# timestamp   NaN
# Name: 293, dtype: float64
# timestamp   NaN
# Name: 295, dtype: float64
# timestamp   NaN
# Name: 297, dtype: float64
# timestamp   NaN
# Name: 299, dtype: float64
# timestamp   NaN
# Name: 301, dtype: float64
# timestamp   NaN
# Name: 303, dtype: float64
# timestamp   NaN
# Name: 305, dtype: float64
# timestamp   NaN
# Name: 307, dtype: float64
# timestamp   NaN
# Name: 309, dtype: float64
# timestamp   NaN
# Name: 311, dtype: float64
# timestamp   NaN
# Name: 313, dtype: float64
# timestamp   NaN
# Name: 315, dtype: float64
# timestamp   NaN
# Name: 317, dtype: float64
# timestamp   NaN
# Name: 319, dtype: float64
# timestamp   NaN
# Name: 321, dtype: float64
# timestamp   NaN
# Name: 323, dtype: float64
# timestamp   NaN
# Name: 325, dtype: float64
# timestamp   NaN
# Name: 327, dtype: float64
# timestamp   NaN
# Name: 329, dtype: float64
# timestamp   NaN
# Name: 331, dtype: float64
# timestamp   NaN
# Name: 333, dtype: float64
# timestamp   NaN
# Name: 335, dtype: float64
# timestamp   NaN
# Name: 337, dtype: float64
# timestamp   NaN
# Name: 339, dtype: float64
# timestamp   NaN
# Name: 341, dtype: float64
# timestamp   NaN
# Name: 343, dtype: float64
# timestamp   NaN
# Name: 345, dtype: float64
# timestamp   NaN
# Name: 347, dtype: float64
# timestamp   NaN
# Name: 349, dtype: float64
# timestamp   NaN
# Name: 351, dtype: float64
# timestamp   NaN
# Name: 353, dtype: float64
# timestamp   NaN
# Name: 355, dtype: float64
# timestamp   NaN
# Name: 357, dtype: float64
# timestamp   NaN
# Name: 359, dtype: float64
# timestamp   NaN
# Name: 361, dtype: float64
# timestamp   NaN
# Name: 363, dtype: float64
# timestamp   NaN
# Name: 365, dtype: float64
# timestamp   NaN
# Name: 367, dtype: float64
# timestamp   NaN
# Name: 369, dtype: float64
# timestamp   NaN
# Name: 371, dtype: float64
# timestamp   NaN
# Name: 373, dtype: float64
# timestamp   NaN
# Name: 375, dtype: float64
# timestamp   NaN
# Name: 377, dtype: float64
# timestamp   NaN
# Name: 379, dtype: float64
# timestamp   NaN
# Name: 381, dtype: float64
# timestamp   NaN
# Name: 383, dtype: float64
# timestamp   NaN
# Name: 385, dtype: float64
# timestamp   NaN
# Name: 387, dtype: float64
# timestamp   NaN
# Name: 389, dtype: float64
# timestamp   NaN
# Name: 391, dtype: float64
# timestamp   NaN
# Name: 393, dtype: float64
# timestamp   NaN
# Name: 395, dtype: float64
# timestamp   NaN
# Name: 397, dtype: float64
# timestamp   NaN
# Name: 399, dtype: float64
# timestamp   NaN
# Name: 401, dtype: float64
# timestamp   NaN
# Name: 403, dtype: float64
# timestamp   NaN
# Name: 405, dtype: float64
# timestamp   NaN
# Name: 407, dtype: float64
# timestamp   NaN
# Name: 409, dtype: float64
# timestamp   NaN
# Name: 411, dtype: float64
# timestamp   NaN
# Name: 413, dtype: float64
# timestamp   NaN
# Name: 415, dtype: float64
# timestamp   NaN
# Name: 417, dtype: float64
# timestamp   NaN
# Name: 419, dtype: float64
# timestamp   NaN
# Name: 421, dtype: float64
# timestamp   NaN
# Name: 423, dtype: float64
# timestamp   NaN
# Name: 425, dtype: float64
# timestamp   NaN
# Name: 427, dtype: float64
# timestamp   NaN
# Name: 429, dtype: float64
# timestamp   NaN
# Name: 431, dtype: float64
# timestamp   NaN
# Name: 433, dtype: float64
# timestamp   NaN
# Name: 435, dtype: float64
# timestamp   NaN
# Name: 437, dtype: float64
# timestamp   NaN
# Name: 439, dtype: float64
# timestamp   NaN
# Name: 441, dtype: float64
# timestamp   NaN
# Name: 443, dtype: float64
# timestamp   NaN
# Name: 445, dtype: float64
# timestamp   NaN
# Name: 447, dtype: float64
# timestamp   NaN
# Name: 449, dtype: float64
# timestamp   NaN
# Name: 451, dtype: float64
# timestamp   NaN
# Name: 453, dtype: float64
# timestamp   NaN
# Name: 455, dtype: float64
# timestamp   NaN
# Name: 457, dtype: float64
# timestamp   NaN
# Name: 459, dtype: float64
# timestamp   NaN
# Name: 461, dtype: float64
# timestamp   NaN
# Name: 463, dtype: float64
# timestamp   NaN
# Name: 465, dtype: float64
# timestamp   NaN
# Name: 467, dtype: float64
# timestamp   NaN
# Name: 469, dtype: float64
# timestamp   NaN
# Name: 471, dtype: float64
# timestamp   NaN
# Name: 473, dtype: float64
# timestamp   NaN
# Name: 475, dtype: float64
# timestamp   NaN
# Name: 477, dtype: float64
# timestamp   NaN
# Name: 479, dtype: float64
# timestamp   NaN
# Name: 481, dtype: float64
# timestamp   NaN
# Name: 483, dtype: float64
# timestamp   NaN
# Name: 485, dtype: float64
# timestamp   NaN
# Name: 487, dtype: float64
# timestamp   NaN
# Name: 489, dtype: float64
# timestamp   NaN
# Name: 491, dtype: float64
# timestamp   NaN
# Name: 493, dtype: float64
# timestamp   NaN
# Name: 495, dtype: float64
# timestamp   NaN
# Name: 497, dtype: float64
# timestamp   NaN
# Name: 499, dtype: float64
# timestamp   NaN
# Name: 501, dtype: float64
# timestamp   NaN
# Name: 503, dtype: float64
# timestamp   NaN
# Name: 505, dtype: float64
# timestamp   NaN
# Name: 507, dtype: float64
# timestamp   NaN
# Name: 509, dtype: float64
# timestamp   NaN
# Name: 511, dtype: float64
# timestamp   NaN
# Name: 513, dtype: float64
# timestamp   NaN
# Name: 515, dtype: float64
# timestamp   NaN
# Name: 517, dtype: float64
# timestamp   NaN
# Name: 519, dtype: float64
# timestamp   NaN
# Name: 521, dtype: float64
# timestamp   NaN
# Name: 523, dtype: float64
# timestamp   NaN
# Name: 525, dtype: float64
# timestamp   NaN
# Name: 527, dtype: float64
# timestamp   NaN
# Name: 529, dtype: float64
# timestamp   NaN
# Name: 531, dtype: float64
# timestamp   NaN
# Name: 533, dtype: float64
# timestamp   NaN
# Name: 535, dtype: float64
# timestamp   NaN
# Name: 537, dtype: float64
# timestamp   NaN
# Name: 539, dtype: float64
# timestamp   NaN
# Name: 541, dtype: float64
# timestamp   NaN
# Name: 543, dtype: float64
# timestamp   NaN
# Name: 545, dtype: float64
# timestamp   NaN
# Name: 547, dtype: float64
# timestamp   NaN
# Name: 549, dtype: float64
# timestamp   NaN
# Name: 551, dtype: float64
# timestamp   NaN
# Name: 553, dtype: float64
# timestamp   NaN
# Name: 555, dtype: float64
# timestamp   NaN
# Name: 557, dtype: float64
# timestamp   NaN
# Name: 559, dtype: float64
# timestamp   NaN
# Name: 561, dtype: float64
# timestamp   NaN
# Name: 563, dtype: float64
# timestamp   NaN
# Name: 565, dtype: float64
# timestamp   NaN
# Name: 567, dtype: float64
# timestamp   NaN
# Name: 569, dtype: float64
# timestamp   NaN
# Name: 571, dtype: float64
# timestamp   NaN
# Name: 573, dtype: float64
# timestamp   NaN
# Name: 575, dtype: float64
# timestamp   NaN
# Name: 577, dtype: float64
# timestamp   NaN
# Name: 579, dtype: float64
# timestamp   NaN
# Name: 581, dtype: float64
# timestamp   NaN
# Name: 583, dtype: float64
# timestamp   NaN
# Name: 585, dtype: float64
# timestamp   NaN
# Name: 587, dtype: float64
# timestamp   NaN
# Name: 589, dtype: float64
# timestamp   NaN
# Name: 591, dtype: float64
# timestamp   NaN
# Name: 593, dtype: float64
# timestamp   NaN
# Name: 595, dtype: float64
# timestamp   NaN
# Name: 597, dtype: float64
# timestamp   NaN
# Name: 599, dtype: float64
# timestamp   NaN
# Name: 601, dtype: float64
# timestamp   NaN
# Name: 603, dtype: float64
# timestamp   NaN
# Name: 605, dtype: float64
# timestamp   NaN
# Name: 607, dtype: float64
# timestamp   NaN
# Name: 609, dtype: float64
# timestamp   NaN
# Name: 611, dtype: float64
# timestamp   NaN
# Name: 613, dtype: float64
# timestamp   NaN
# Name: 615, dtype: float64
# timestamp   NaN
# Name: 617, dtype: float64
# timestamp   NaN
# Name: 619, dtype: float64
# timestamp   NaN
# Name: 621, dtype: float64
# timestamp   NaN
# Name: 623, dtype: float64
# timestamp   NaN
# Name: 625, dtype: float64
# timestamp   NaN
# Name: 627, dtype: float64
# timestamp   NaN
# Name: 629, dtype: float64
# timestamp   NaN
# Name: 631, dtype: float64
# timestamp   NaN
# Name: 633, dtype: float64
# timestamp   NaN
# Name: 635, dtype: float64
# timestamp   NaN
# Name: 637, dtype: float64
# timestamp   NaN
# Name: 639, dtype: float64
# timestamp   NaN
# Name: 641, dtype: float64
# timestamp   NaN
# Name: 643, dtype: float64
# timestamp   NaN
# Name: 645, dtype: float64
# timestamp   NaN
# Name: 647, dtype: float64
# timestamp   NaN
# Name: 649, dtype: float64
# timestamp   NaN
# Name: 651, dtype: float64
# timestamp   NaN
# Name: 653, dtype: float64
# timestamp   NaN
# Name: 655, dtype: float64
# timestamp   NaN
# Name: 657, dtype: float64
# timestamp   NaN
# Name: 659, dtype: float64
# timestamp   NaN
# Name: 661, dtype: float64
# timestamp   NaN
# Name: 663, dtype: float64
# timestamp   NaN
# Name: 665, dtype: float64
# timestamp   NaN
# Name: 667, dtype: float64
# timestamp   NaN
# Name: 669, dtype: float64
# timestamp   NaN
# Name: 671, dtype: float64
# timestamp   NaN
# Name: 673, dtype: float64
# timestamp   NaN
# Name: 675, dtype: float64
# timestamp   NaN
# Name: 677, dtype: float64
# timestamp   NaN
# Name: 679, dtype: float64
# timestamp   NaN
# Name: 681, dtype: float64
# timestamp   NaN
# Name: 683, dtype: float64
# timestamp   NaN
# Name: 685, dtype: float64
# timestamp   NaN
# Name: 687, dtype: float64
# timestamp   NaN
# Name: 689, dtype: float64
# timestamp   NaN
# Name: 691, dtype: float64
# timestamp   NaN
# Name: 693, dtype: float64
# timestamp   NaN
# Name: 695, dtype: float64
# timestamp   NaN
# Name: 697, dtype: float64
# timestamp   NaN
# Name: 699, dtype: float64
# timestamp   NaN
# Name: 701, dtype: float64
# timestamp   NaN
# Name: 703, dtype: float64
# timestamp   NaN
# Name: 705, dtype: float64
# timestamp   NaN
# Name: 707, dtype: float64
# timestamp   NaN
# Name: 709, dtype: float64
# timestamp   NaN
# Name: 711, dtype: float64
# timestamp   NaN
# Name: 713, dtype: float64
# timestamp   NaN
# Name: 715, dtype: float64
# timestamp   NaN
# Name: 717, dtype: float64
# timestamp   NaN
# Name: 719, dtype: float64
# timestamp   NaN
# Name: 721, dtype: float64
# timestamp   NaN
# Name: 723, dtype: float64
# timestamp   NaN
# Name: 725, dtype: float64
# timestamp   NaN
# Name: 727, dtype: float64
# timestamp   NaN
# Name: 729, dtype: float64
# timestamp   NaN
# Name: 731, dtype: float64
# timestamp   NaN
# Name: 733, dtype: float64
# timestamp   NaN
# Name: 735, dtype: float64
# timestamp   NaN
# Name: 737, dtype: float64
# timestamp   NaN
# Name: 739, dtype: float64
# timestamp   NaN
# Name: 741, dtype: float64
# timestamp   NaN
# Name: 743, dtype: float64
# timestamp   NaN
# Name: 745, dtype: float64
# timestamp   NaN
# Name: 747, dtype: float64
# timestamp   NaN
# Name: 749, dtype: float64
# timestamp   NaN
# Name: 751, dtype: float64
# timestamp   NaN
# Name: 753, dtype: float64
# timestamp   NaN
# Name: 755, dtype: float64
# timestamp   NaN
# Name: 757, dtype: float64
# timestamp   NaN
# Name: 759, dtype: float64
# timestamp   NaN
# Name: 761, dtype: float64
# timestamp   NaN
# Name: 763, dtype: float64
# timestamp   NaN
# Name: 765, dtype: float64
# timestamp   NaN
# Name: 767, dtype: float64
# timestamp   NaN
# Name: 769, dtype: float64
# timestamp   NaN
# Name: 771, dtype: float64
# timestamp   NaN
# Name: 773, dtype: float64
# timestamp   NaN
# Name: 775, dtype: float64
# timestamp   NaN
# Name: 777, dtype: float64
# timestamp   NaN
# Name: 779, dtype: float64
# timestamp   NaN
# Name: 781, dtype: float64
# timestamp   NaN
# Name: 783, dtype: float64
# timestamp   NaN
# Name: 785, dtype: float64
# timestamp   NaN
# Name: 787, dtype: float64
# timestamp   NaN
# Name: 789, dtype: float64
# timestamp   NaN
# Name: 791, dtype: float64
# timestamp   NaN
# Name: 793, dtype: float64
# timestamp   NaN
# Name: 795, dtype: float64
# timestamp   NaN
# Name: 797, dtype: float64
# timestamp   NaN
# Name: 799, dtype: float64
# timestamp   NaN
# Name: 801, dtype: float64
# timestamp   NaN
# Name: 803, dtype: float64
# timestamp   NaN
# Name: 805, dtype: float64
# timestamp   NaN
# Name: 807, dtype: float64
# timestamp   NaN
# Name: 809, dtype: float64
# timestamp   NaN
# Name: 811, dtype: float64
# timestamp   NaN
# Name: 813, dtype: float64
# timestamp   NaN
# Name: 815, dtype: float64
# timestamp   NaN
# Name: 817, dtype: float64
# timestamp   NaN
# Name: 819, dtype: float64
# timestamp   NaN
# Name: 821, dtype: float64
# timestamp   NaN
# Name: 823, dtype: float64
# timestamp   NaN
# Name: 825, dtype: float64
# timestamp   NaN
# Name: 827, dtype: float64
# timestamp   NaN
# Name: 829, dtype: float64
# timestamp   NaN
# Name: 831, dtype: float64
# timestamp   NaN
# Name: 833, dtype: float64
# timestamp   NaN
# Name: 835, dtype: float64
# timestamp   NaN
# Name: 837, dtype: float64
# timestamp   NaN
# Name: 839, dtype: float64
# timestamp   NaN
# Name: 841, dtype: float64
# timestamp   NaN
# Name: 843, dtype: float64
# timestamp   NaN
# Name: 845, dtype: float64
# timestamp   NaN
# Name: 847, dtype: float64
# timestamp   NaN
# Name: 849, dtype: float64
# timestamp   NaN
# Name: 851, dtype: float64
# timestamp   NaN
# Name: 853, dtype: float64
# timestamp   NaN
# Name: 855, dtype: float64
# timestamp   NaN
# Name: 857, dtype: float64
# timestamp   NaN
# Name: 859, dtype: float64
# timestamp   NaN
# Name: 861, dtype: float64
# timestamp   NaN
# Name: 863, dtype: float64
# timestamp   NaN
# Name: 865, dtype: float64
# timestamp   NaN
# Name: 867, dtype: float64
# timestamp   NaN
# Name: 869, dtype: float64
# timestamp   NaN
# Name: 871, dtype: float64
# timestamp   NaN
# Name: 873, dtype: float64
# timestamp   NaN
# Name: 875, dtype: float64
# timestamp   NaN
# Name: 877, dtype: float64
# timestamp   NaN
# Name: 879, dtype: float64
# timestamp   NaN
# Name: 881, dtype: float64
# timestamp   NaN
# Name: 883, dtype: float64
# timestamp   NaN
# Name: 885, dtype: float64
# timestamp   NaN
# Name: 887, dtype: float64
# timestamp   NaN
# Name: 889, dtype: float64
# timestamp   NaN
# Name: 891, dtype: float64
# timestamp   NaN
# Name: 893, dtype: float64
# timestamp   NaN
# Name: 895, dtype: float64
# timestamp   NaN
# Name: 897, dtype: float64
# timestamp   NaN
# Name: 899, dtype: float64
# timestamp   NaN
# Name: 901, dtype: float64
# timestamp   NaN
# Name: 903, dtype: float64
# timestamp   NaN
# Name: 905, dtype: float64
# timestamp   NaN
# Name: 907, dtype: float64
# timestamp   NaN
# Name: 909, dtype: float64
# timestamp   NaN
# Name: 911, dtype: float64
# timestamp   NaN
# Name: 913, dtype: float64
# timestamp   NaN
# Name: 915, dtype: float64
# timestamp   NaN
# Name: 917, dtype: float64
# timestamp   NaN
# Name: 919, dtype: float64
# timestamp   NaN
# Name: 921, dtype: float64
# timestamp   NaN
# Name: 923, dtype: float64
# timestamp   NaN
# Name: 925, dtype: float64
# timestamp   NaN
# Name: 927, dtype: float64
# timestamp   NaN
# Name: 929, dtype: float64
# timestamp   NaN
# Name: 931, dtype: float64
# timestamp   NaN
# Name: 933, dtype: float64
# timestamp   NaN
# Name: 935, dtype: float64
# timestamp   NaN
# Name: 937, dtype: float64
# timestamp   NaN
# Name: 939, dtype: float64
# timestamp   NaN
# Name: 941, dtype: float64
# timestamp   NaN
# Name: 943, dtype: float64
# timestamp   NaN
# Name: 945, dtype: float64
# timestamp   NaN
# Name: 947, dtype: float64
# timestamp   NaN
# Name: 949, dtype: float64
# timestamp   NaN
# Name: 951, dtype: float64
# timestamp   NaN
# Name: 953, dtype: float64
# timestamp   NaN
# Name: 955, dtype: float64
# timestamp   NaN
# Name: 957, dtype: float64
# timestamp   NaN
# Name: 959, dtype: float64
# timestamp   NaN
# Name: 961, dtype: float64
# timestamp   NaN
# Name: 963, dtype: float64
# timestamp   NaN
# Name: 965, dtype: float64
# timestamp   NaN
# Name: 967, dtype: float64
# timestamp   NaN
# Name: 969, dtype: float64
# timestamp   NaN
# Name: 971, dtype: float64
# timestamp   NaN
# Name: 973, dtype: float64
# timestamp   NaN
# Name: 975, dtype: float64
# timestamp   NaN
# Name: 977, dtype: float64
# timestamp   NaN
# Name: 979, dtype: float64
# timestamp   NaN
# Name: 981, dtype: float64
# timestamp   NaN
# Name: 983, dtype: float64
# timestamp   NaN
# Name: 985, dtype: float64
# timestamp   NaN
# Name: 987, dtype: float64
# timestamp   NaN
# Name: 989, dtype: float64
# timestamp   NaN
# Name: 991, dtype: float64
# timestamp   NaN
# Name: 993, dtype: float64
# timestamp   NaN
# Name: 995, dtype: float64
# timestamp   NaN
# Name: 997, dtype: float64
# timestamp   NaN
# Name: 999, dtype: float64
# timestamp   NaN
# Name: 1001, dtype: float64
# timestamp   NaN
# Name: 1003, dtype: float64
# timestamp   NaN
# Name: 1005, dtype: float64
# timestamp   NaN
# Name: 1007, dtype: float64
# timestamp   NaN
# Name: 1009, dtype: float64
# timestamp   NaN
# Name: 1011, dtype: float64
# timestamp   NaN
# Name: 1013, dtype: float64
# timestamp   NaN
# Name: 1015, dtype: float64
# timestamp   NaN
# Name: 1017, dtype: float64
# timestamp   NaN
# Name: 1019, dtype: float64
# timestamp   NaN
# Name: 1021, dtype: float64
# timestamp   NaN
# Name: 1023, dtype: float64
# timestamp   NaN
# Name: 1025, dtype: float64
# timestamp   NaN
# Name: 1027, dtype: float64
# timestamp   NaN
# Name: 1029, dtype: float64
# timestamp   NaN
# Name: 1031, dtype: float64
# timestamp   NaN
# Name: 1033, dtype: float64
# timestamp   NaN
# Name: 1035, dtype: float64
# timestamp   NaN
# Name: 1037, dtype: float64
# timestamp   NaN
# Name: 1039, dtype: float64
# timestamp   NaN
# Name: 1041, dtype: float64
# timestamp   NaN
# Name: 1043, dtype: float64
# timestamp   NaN
# Name: 1045, dtype: float64
# timestamp   NaN
# Name: 1047, dtype: float64
# timestamp   NaN
# Name: 1049, dtype: float64
# timestamp   NaN
# Name: 1051, dtype: float64
# timestamp   NaN
# Name: 1053, dtype: float64
# timestamp   NaN
# Name: 1055, dtype: float64
# timestamp   NaN
# Name: 1057, dtype: float64
# timestamp   NaN
# Name: 1059, dtype: float64
# timestamp   NaN
# Name: 1061, dtype: float64
# timestamp   NaN
# Name: 1063, dtype: float64
# timestamp   NaN
# Name: 1065, dtype: float64
# timestamp   NaN
# Name: 1067, dtype: float64
# timestamp   NaN
# Name: 1069, dtype: float64
# timestamp   NaN
# Name: 1071, dtype: float64
# timestamp   NaN
# Name: 1073, dtype: float64
# timestamp   NaN
# Name: 1075, dtype: float64
# timestamp   NaN
# Name: 1077, dtype: float64
# timestamp   NaN
# Name: 1079, dtype: float64
# timestamp   NaN
# Name: 1081, dtype: float64
# timestamp   NaN
# Name: 1083, dtype: float64
# timestamp   NaN
# Name: 1085, dtype: float64
# timestamp   NaN
# Name: 1087, dtype: float64
# timestamp   NaN
# Name: 1089, dtype: float64
# timestamp   NaN
# Name: 1091, dtype: float64
# timestamp   NaN
# Name: 1093, dtype: float64
# timestamp   NaN
# Name: 1095, dtype: float64
# timestamp   NaN
# Name: 1097, dtype: float64
# timestamp   NaN
# Name: 1099, dtype: float64
# timestamp   NaN
# Name: 1101, dtype: float64
# timestamp   NaN
# Name: 1103, dtype: float64
# timestamp   NaN
# Name: 1105, dtype: float64
# timestamp   NaN
# Name: 1107, dtype: float64
# timestamp   NaN
# Name: 1109, dtype: float64
# timestamp   NaN
# Name: 1111, dtype: float64
# timestamp   NaN
# Name: 1113, dtype: float64
# timestamp   NaN
# Name: 1115, dtype: float64
# timestamp   NaN
# Name: 1117, dtype: float64
# timestamp   NaN
# Name: 1119, dtype: float64
# timestamp   NaN
# Name: 1121, dtype: float64
# timestamp   NaN
# Name: 1123, dtype: float64
# timestamp   NaN
# Name: 1125, dtype: float64
# timestamp   NaN
# Name: 1127, dtype: float64
# timestamp   NaN
# Name: 1129, dtype: float64
# timestamp   NaN
# Name: 1131, dtype: float64
# timestamp   NaN
# Name: 1133, dtype: float64
# timestamp   NaN
# Name: 1135, dtype: float64
# timestamp   NaN
# Name: 1137, dtype: float64
# timestamp   NaN
# Name: 1139, dtype: float64
# timestamp   NaN
# Name: 1141, dtype: float64
# timestamp   NaN
# Name: 1143, dtype: float64
# timestamp   NaN
# Name: 1145, dtype: float64
# timestamp   NaN
# Name: 1147, dtype: float64
# timestamp   NaN
# Name: 1149, dtype: float64
# timestamp   NaN
# Name: 1151, dtype: float64
# timestamp   NaN
# Name: 1153, dtype: float64
# timestamp   NaN
# Name: 1155, dtype: float64
# timestamp   NaN
# Name: 1157, dtype: float64
# timestamp   NaN
# Name: 1159, dtype: float64
# timestamp   NaN
# Name: 1161, dtype: float64
# timestamp   NaN
# Name: 1163, dtype: float64
# timestamp   NaN
# Name: 1165, dtype: float64
# timestamp   NaN
# Name: 1167, dtype: float64
# timestamp   NaN
# Name: 1169, dtype: float64
# timestamp   NaN
# Name: 1171, dtype: float64
# timestamp   NaN
# Name: 1173, dtype: float64
# timestamp   NaN
# Name: 1175, dtype: float64
# timestamp   NaN
# Name: 1177, dtype: float64
# timestamp   NaN
# Name: 1179, dtype: float64
# timestamp   NaN
# Name: 1181, dtype: float64
# timestamp   NaN
# Name: 1183, dtype: float64
# timestamp   NaN
# Name: 1185, dtype: float64
# timestamp   NaN
# Name: 1187, dtype: float64
# timestamp   NaN
# Name: 1189, dtype: float64
# timestamp   NaN
# Name: 1191, dtype: float64
# timestamp   NaN
# Name: 1193, dtype: float64
# timestamp   NaN
# Name: 1195, dtype: float64
# timestamp   NaN
# Name: 1197, dtype: float64
# timestamp   NaN
# Name: 1199, dtype: float64
# timestamp   NaN
# Name: 1201, dtype: float64
# timestamp   NaN
# Name: 1203, dtype: float64
# timestamp   NaN
# Name: 1205, dtype: float64
# timestamp   NaN
# Name: 1207, dtype: float64
# timestamp   NaN
# Name: 1209, dtype: float64
# timestamp   NaN
# Name: 1211, dtype: float64
# timestamp   NaN
# Name: 1213, dtype: float64
# timestamp   NaN
# Name: 1215, dtype: float64
# timestamp   NaN
# Name: 1217, dtype: float64
# timestamp   NaN
# Name: 1219, dtype: float64
# timestamp   NaN
# Name: 1221, dtype: float64
# timestamp   NaN
# Name: 1223, dtype: float64
# timestamp   NaN
# Name: 1225, dtype: float64
# timestamp   NaN
# Name: 1227, dtype: float64
# timestamp   NaN
# Name: 1229, dtype: float64
# timestamp   NaN
# Name: 1231, dtype: float64
# timestamp   NaN
# Name: 1233, dtype: float64
# timestamp   NaN
# Name: 1235, dtype: float64
# timestamp   NaN
# Name: 1237, dtype: float64
# timestamp   NaN
# Name: 1239, dtype: float64
# timestamp   NaN
# Name: 1241, dtype: float64
# timestamp   NaN
# Name: 1243, dtype: float64
# timestamp   NaN
# Name: 1245, dtype: float64
# timestamp   NaN
# Name: 1247, dtype: float64
# timestamp   NaN
# Name: 1249, dtype: float64
# timestamp   NaN
# Name: 1251, dtype: float64
# timestamp   NaN
# Name: 1253, dtype: float64
# timestamp   NaN
# Name: 1255, dtype: float64
# timestamp   NaN
# Name: 1257, dtype: float64
# timestamp   NaN
# Name: 1259, dtype: float64
# timestamp   NaN
# Name: 1261, dtype: float64
# timestamp   NaN
# Name: 1263, dtype: float64
# timestamp   NaN
# Name: 1265, dtype: float64
# timestamp   NaN
# Name: 1267, dtype: float64
# timestamp   NaN
# Name: 1269, dtype: float64
# timestamp   NaN
# Name: 1271, dtype: float64
# timestamp   NaN
# Name: 1273, dtype: float64
# timestamp   NaN
# Name: 1275, dtype: float64
# timestamp   NaN
# Name: 1277, dtype: float64
# timestamp   NaN
# Name: 1279, dtype: float64
# timestamp   NaN
# Name: 1281, dtype: float64
# timestamp   NaN
# Name: 1283, dtype: float64
# timestamp   NaN
# Name: 1285, dtype: float64
# timestamp   NaN
# Name: 1287, dtype: float64
# timestamp   NaN
# Name: 1289, dtype: float64
# timestamp   NaN
# Name: 1291, dtype: float64
# timestamp   NaN
# Name: 1293, dtype: float64
# timestamp   NaN
# Name: 1295, dtype: float64
# timestamp   NaN
# Name: 1297, dtype: float64
# timestamp   NaN
# Name: 1299, dtype: float64
# timestamp   NaN
# Name: 1301, dtype: float64
# timestamp   NaN
# Name: 1303, dtype: float64
# timestamp   NaN
# Name: 1305, dtype: float64
# timestamp   NaN
# Name: 1307, dtype: float64
# timestamp   NaN
# Name: 1309, dtype: float64
# timestamp   NaN
# Name: 1311, dtype: float64
# timestamp   NaN
# Name: 1313, dtype: float64
# timestamp   NaN
# Name: 1315, dtype: float64
# timestamp   NaN
# Name: 1317, dtype: float64
# timestamp   NaN
# Name: 1319, dtype: float64
# timestamp   NaN
# Name: 1321, dtype: float64
# timestamp   NaN
# Name: 1323, dtype: float64
# timestamp   NaN
# Name: 1325, dtype: float64
# timestamp   NaN
# Name: 1327, dtype: float64
# timestamp   NaN
# Name: 1329, dtype: float64
# timestamp   NaN
# Name: 1331, dtype: float64
# timestamp   NaN
# Name: 1333, dtype: float64
# timestamp   NaN
# Name: 1335, dtype: float64
# timestamp   NaN
# Name: 1337, dtype: float64
# timestamp   NaN
# Name: 1339, dtype: float64
# timestamp   NaN
# Name: 1341, dtype: float64
# timestamp   NaN
# Name: 1343, dtype: float64
# timestamp   NaN
# Name: 1345, dtype: float64
# timestamp   NaN
# Name: 1347, dtype: float64
# timestamp   NaN
# Name: 1349, dtype: float64
# timestamp   NaN
# Name: 1351, dtype: float64
# timestamp   NaN
# Name: 1353, dtype: float64
# timestamp   NaN
# Name: 1355, dtype: float64
# timestamp   NaN
# Name: 1357, dtype: float64
# timestamp   NaN
# Name: 1359, dtype: float64
# timestamp   NaN
# Name: 1361, dtype: float64
# timestamp   NaN
# Name: 1363, dtype: float64
# timestamp   NaN
# Name: 1365, dtype: float64
# timestamp   NaN
# Name: 1367, dtype: float64
# timestamp   NaN
# Name: 1369, dtype: float64
# timestamp   NaN
# Name: 1371, dtype: float64
# timestamp   NaN
# Name: 1373, dtype: float64
# timestamp   NaN
# Name: 1375, dtype: float64
# timestamp   NaN
# Name: 1377, dtype: float64
# timestamp   NaN
# Name: 1379, dtype: float64
# timestamp   NaN
# Name: 1381, dtype: float64
# timestamp   NaN
# Name: 1383, dtype: float64
# timestamp   NaN
# Name: 1385, dtype: float64
# timestamp   NaN
# Name: 1387, dtype: float64
# timestamp   NaN
# Name: 1389, dtype: float64
# timestamp   NaN
# Name: 1391, dtype: float64
# timestamp   NaN
# Name: 1393, dtype: float64
# timestamp   NaN
# Name: 1395, dtype: float64
# timestamp   NaN
# Name: 1397, dtype: float64
# timestamp   NaN
# Name: 1399, dtype: float64
# timestamp   NaN
# Name: 1401, dtype: float64
# timestamp   NaN
# Name: 1403, dtype: float64
# timestamp   NaN
# Name: 1405, dtype: float64
# timestamp   NaN
# Name: 1407, dtype: float64
# timestamp   NaN
# Name: 1409, dtype: float64
# timestamp   NaN
# Name: 1411, dtype: float64
# timestamp   NaN
# Name: 1413, dtype: float64
# timestamp   NaN
# Name: 1415, dtype: float64
# timestamp   NaN
# Name: 1417, dtype: float64
# timestamp   NaN
# Name: 1419, dtype: float64
# timestamp   NaN
# Name: 1421, dtype: float64
# timestamp   NaN
# Name: 1423, dtype: float64
# timestamp   NaN
# Name: 1425, dtype: float64
# timestamp   NaN
# Name: 1427, dtype: float64
# timestamp   NaN
# Name: 1429, dtype: float64
# timestamp   NaN
# Name: 1431, dtype: float64
# timestamp   NaN
# Name: 1433, dtype: float64
# timestamp   NaN
# Name: 1435, dtype: float64
# timestamp   NaN
# Name: 1437, dtype: float64
# timestamp   NaN
# Name: 1439, dtype: float64
# timestamp   NaN
# Name: 1441, dtype: float64
# timestamp   NaN
# Name: 1443, dtype: float64
# timestamp   NaN
# Name: 1445, dtype: float64
# timestamp   NaN
# Name: 1447, dtype: float64
# timestamp   NaN
# Name: 1449, dtype: float64
# timestamp   NaN
# Name: 1451, dtype: float64
# timestamp   NaN
# Name: 1453, dtype: float64
# timestamp   NaN
# Name: 1455, dtype: float64
# timestamp   NaN
# Name: 1457, dtype: float64
# timestamp   NaN
# Name: 1459, dtype: float64
# timestamp   NaN
# Name: 1461, dtype: float64
# timestamp   NaN
# Name: 1463, dtype: float64
# timestamp   NaN
# Name: 1465, dtype: float64
# timestamp   NaN
# Name: 1467, dtype: float64
# timestamp   NaN
# Name: 1469, dtype: float64
# timestamp   NaN
# Name: 1471, dtype: float64
# timestamp   NaN
# Name: 1473, dtype: float64
# timestamp   NaN
# Name: 1475, dtype: float64
# timestamp   NaN
# Name: 1477, dtype: float64
# timestamp   NaN
# Name: 1479, dtype: float64
# timestamp   NaN
# Name: 1481, dtype: float64
# timestamp   NaN
# Name: 1483, dtype: float64
# timestamp   NaN
# Name: 1485, dtype: float64
# timestamp   NaN
# Name: 1487, dtype: float64
# timestamp   NaN
# Name: 1489, dtype: float64
# timestamp   NaN
# Name: 1491, dtype: float64
# timestamp   NaN
# Name: 1493, dtype: float64
# timestamp   NaN
# Name: 1495, dtype: float64
# timestamp   NaN
# Name: 1497, dtype: float64
# timestamp   NaN
# Name: 1499, dtype: float64
# timestamp   NaN
# Name: 1501, dtype: float64
# timestamp   NaN
# Name: 1503, dtype: float64
# timestamp   NaN
# Name: 1505, dtype: float64
# timestamp   NaN
# Name: 1507, dtype: float64
# timestamp   NaN
# Name: 1509, dtype: float64
# timestamp   NaN
# Name: 1511, dtype: float64
# timestamp   NaN
# Name: 1513, dtype: float64
# timestamp   NaN
# Name: 1515, dtype: float64
# timestamp   NaN
# Name: 1517, dtype: float64
# timestamp   NaN
# Name: 1519, dtype: float64
# timestamp   NaN
# Name: 1521, dtype: float64
# timestamp   NaN
# Name: 1523, dtype: float64
# timestamp   NaN
# Name: 1525, dtype: float64
# timestamp   NaN
# Name: 1527, dtype: float64
# timestamp   NaN
# Name: 1529, dtype: float64
# timestamp   NaN
# Name: 1531, dtype: float64
# timestamp   NaN
# Name: 1533, dtype: float64
# timestamp   NaN
# Name: 1535, dtype: float64
# timestamp   NaN
# Name: 1537, dtype: float64
# timestamp   NaN
# Name: 1539, dtype: float64
# timestamp   NaN
# Name: 1541, dtype: float64
# timestamp   NaN
# Name: 1543, dtype: float64
# timestamp   NaN
# Name: 1545, dtype: float64
# timestamp   NaN
# Name: 1547, dtype: float64
# timestamp   NaN
# Name: 1549, dtype: float64
# timestamp   NaN
# Name: 1551, dtype: float64
# timestamp   NaN
# Name: 1553, dtype: float64
# timestamp   NaN
# Name: 1555, dtype: float64
# timestamp   NaN
# Name: 1557, dtype: float64
# timestamp   NaN
# Name: 1559, dtype: float64
# timestamp   NaN
# Name: 1561, dtype: float64
# timestamp   NaN
# Name: 1563, dtype: float64
# timestamp   NaN
# Name: 1565, dtype: float64
# timestamp   NaN
# Name: 1567, dtype: float64
# timestamp   NaN
# Name: 1569, dtype: float64
# timestamp   NaN
# Name: 1571, dtype: float64
# timestamp   NaN
# Name: 1573, dtype: float64
# timestamp   NaN
# Name: 1575, dtype: float64
# timestamp   NaN
# Name: 1577, dtype: float64
# timestamp   NaN
# Name: 1579, dtype: float64
# timestamp   NaN
# Name: 1581, dtype: float64
# timestamp   NaN
# Name: 1583, dtype: float64
# timestamp   NaN
# Name: 1585, dtype: float64
# timestamp   NaN
# Name: 1587, dtype: float64
# timestamp   NaN
# Name: 1589, dtype: float64
# timestamp   NaN
# Name: 1591, dtype: float64
# timestamp   NaN
# Name: 1593, dtype: float64
# timestamp   NaN
# Name: 1595, dtype: float64
# timestamp   NaN
# Name: 1597, dtype: float64
# timestamp   NaN
# Name: 1599, dtype: float64
# timestamp   NaN
# Name: 1601, dtype: float64
# timestamp   NaN
# Name: 1603, dtype: float64
# timestamp   NaN
# Name: 1605, dtype: float64
# timestamp   NaN
# Name: 1607, dtype: float64
# timestamp   NaN
# Name: 1609, dtype: float64
# timestamp   NaN
# Name: 1611, dtype: float64
# timestamp   NaN
# Name: 1613, dtype: float64
# timestamp   NaN
# Name: 1615, dtype: float64
# timestamp   NaN
# Name: 1617, dtype: float64
# timestamp   NaN
# Name: 1619, dtype: float64
# timestamp   NaN
# Name: 1621, dtype: float64
# timestamp   NaN
# Name: 1623, dtype: float64
# timestamp   NaN
# Name: 1625, dtype: float64
# timestamp   NaN
# Name: 1627, dtype: float64
# timestamp   NaN
# Name: 1629, dtype: float64
# timestamp   NaN
# Name: 1631, dtype: float64
# timestamp   NaN
# Name: 1633, dtype: float64
# timestamp   NaN
# Name: 1635, dtype: float64
# timestamp   NaN
# Name: 1637, dtype: float64
# timestamp   NaN
# Name: 1639, dtype: float64
# timestamp   NaN
# Name: 1641, dtype: float64
# timestamp   NaN
# Name: 1643, dtype: float64
# timestamp   NaN
# Name: 1645, dtype: float64
# timestamp   NaN
# Name: 1647, dtype: float64
# timestamp   NaN
# Name: 1649, dtype: float64
# timestamp   NaN
# Name: 1651, dtype: float64
# timestamp   NaN
# Name: 1653, dtype: float64
# timestamp   NaN
# Name: 1655, dtype: float64
# timestamp   NaN
# Name: 1657, dtype: float64
# timestamp   NaN
# Name: 1659, dtype: float64
# timestamp   NaN
# Name: 1661, dtype: float64
# timestamp   NaN
# Name: 1663, dtype: float64
# timestamp   NaN
# Name: 1665, dtype: float64
# timestamp   NaN
# Name: 1667, dtype: float64
# timestamp   NaN
# Name: 1669, dtype: float64
# timestamp   NaN
# Name: 1671, dtype: float64
# timestamp   NaN
# Name: 1673, dtype: float64
# timestamp   NaN
# Name: 1675, dtype: float64
# timestamp   NaN
# Name: 1677, dtype: float64
# timestamp   NaN
# Name: 1679, dtype: float64
# timestamp   NaN
# Name: 1681, dtype: float64
# timestamp   NaN
# Name: 1683, dtype: float64
# timestamp   NaN
# Name: 1685, dtype: float64
# timestamp   NaN
# Name: 1687, dtype: float64
# timestamp   NaN
# Name: 1689, dtype: float64
# timestamp   NaN
# Name: 1691, dtype: float64
# timestamp   NaN
# Name: 1693, dtype: float64
# timestamp   NaN
# Name: 1695, dtype: float64
# timestamp   NaN
# Name: 1697, dtype: float64
# timestamp   NaN
# Name: 1699, dtype: float64
# timestamp   NaN
# Name: 1701, dtype: float64
# timestamp   NaN
# Name: 1703, dtype: float64
# timestamp   NaN
# Name: 1705, dtype: float64
# timestamp   NaN
# Name: 1707, dtype: float64
# timestamp   NaN
# Name: 1709, dtype: float64
# timestamp   NaN
# Name: 1711, dtype: float64
# timestamp   NaN
# Name: 1713, dtype: float64
# timestamp   NaN
# Name: 1715, dtype: float64
# timestamp   NaN
# Name: 1717, dtype: float64
# timestamp   NaN
# Name: 1719, dtype: float64
# timestamp   NaN
# Name: 1721, dtype: float64
# timestamp   NaN
# Name: 1723, dtype: float64
# timestamp   NaN
# Name: 1725, dtype: float64
# timestamp   NaN
# Name: 1727, dtype: float64
# timestamp   NaN
# Name: 1729, dtype: float64
# timestamp   NaN
# Name: 1731, dtype: float64
# timestamp   NaN
# Name: 1733, dtype: float64
# timestamp   NaN
# Name: 1735, dtype: float64
# timestamp   NaN
# Name: 1737, dtype: float64
# timestamp   NaN
# Name: 1739, dtype: float64
# timestamp   NaN
# Name: 1741, dtype: float64
# timestamp   NaN
# Name: 1743, dtype: float64
# timestamp   NaN
# Name: 1745, dtype: float64
# timestamp   NaN
# Name: 1747, dtype: float64
# timestamp   NaN
# Name: 1749, dtype: float64
# timestamp   NaN
# Name: 1751, dtype: float64
# timestamp   NaN
# Name: 1753, dtype: float64
# timestamp   NaN
# Name: 1755, dtype: float64
# timestamp   NaN
# Name: 1757, dtype: float64
# timestamp   NaN
# Name: 1759, dtype: float64
# timestamp   NaN
# Name: 1761, dtype: float64
# timestamp   NaN
# Name: 1763, dtype: float64
# timestamp   NaN
# Name: 1765, dtype: float64
# timestamp   NaN
# Name: 1767, dtype: float64
# timestamp   NaN
# Name: 1769, dtype: float64
# timestamp   NaN
# Name: 1771, dtype: float64
# timestamp   NaN
# Name: 1773, dtype: float64
# timestamp   NaN
# Name: 1775, dtype: float64
# timestamp   NaN
# Name: 1777, dtype: float64
# timestamp   NaN
# Name: 1779, dtype: float64
# timestamp   NaN
# Name: 1781, dtype: float64
# timestamp   NaN
# Name: 1783, dtype: float64
# timestamp   NaN
# Name: 1785, dtype: float64
# timestamp   NaN
# Name: 1787, dtype: float64
# timestamp   NaN
# Name: 1789, dtype: float64
# timestamp   NaN
# Name: 1791, dtype: float64
# timestamp   NaN
# Name: 1793, dtype: float64
# timestamp   NaN
# Name: 1795, dtype: float64
# timestamp   NaN
# Name: 1797, dtype: float64
# timestamp   NaN
# Name: 1799, dtype: float64
# timestamp   NaN
# Name: 1801, dtype: float64
# timestamp   NaN
# Name: 1803, dtype: float64
# timestamp   NaN
# Name: 1805, dtype: float64
# timestamp   NaN
# Name: 1807, dtype: float64
# timestamp   NaN
# Name: 1809, dtype: float64
# timestamp   NaN
# Name: 1811, dtype: float64
# timestamp   NaN
# Name: 1813, dtype: float64
# timestamp   NaN
# Name: 1815, dtype: float64
# timestamp   NaN
# Name: 1817, dtype: float64
# timestamp   NaN
# Name: 1819, dtype: float64
# timestamp   NaN
# Name: 1821, dtype: float64
# timestamp   NaN
# Name: 1823, dtype: float64
# timestamp   NaN
# Name: 1825, dtype: float64
# timestamp   NaN
# Name: 1827, dtype: float64
# timestamp   NaN
# Name: 1829, dtype: float64
# timestamp   NaN
# Name: 1831, dtype: float64
# timestamp   NaN
# Name: 1833, dtype: float64
# timestamp   NaN
# Name: 1835, dtype: float64
# timestamp   NaN
# Name: 1837, dtype: float64
# timestamp   NaN
# Name: 1839, dtype: float64
# timestamp   NaN
# Name: 1841, dtype: float64
# timestamp   NaN
# Name: 1843, dtype: float64
# timestamp   NaN
# Name: 1845, dtype: float64
# timestamp   NaN
# Name: 1847, dtype: float64
# timestamp   NaN
# Name: 1849, dtype: float64
# timestamp   NaN
# Name: 1851, dtype: float64
# timestamp   NaN
# Name: 1853, dtype: float64
# timestamp   NaN
# Name: 1855, dtype: float64
# timestamp   NaN
# Name: 1857, dtype: float64
# timestamp   NaN
# Name: 1859, dtype: float64
# timestamp   NaN
# Name: 1861, dtype: float64
# timestamp   NaN
# Name: 1863, dtype: float64
# timestamp   NaN
# Name: 1865, dtype: float64
# timestamp   NaN
# Name: 1867, dtype: float64
# timestamp   NaN
# Name: 1869, dtype: float64
# timestamp   NaN
# Name: 1871, dtype: float64
# timestamp   NaN
# Name: 1873, dtype: float64
# timestamp   NaN
# Name: 1875, dtype: float64
# timestamp   NaN
# Name: 1877, dtype: float64
# timestamp   NaN
# Name: 1879, dtype: float64
# timestamp   NaN
# Name: 1881, dtype: float64
# timestamp   NaN
# Name: 1883, dtype: float64
# timestamp   NaN
# Name: 1885, dtype: float64
# timestamp   NaN
# Name: 1887, dtype: float64
# timestamp   NaN
# Name: 1889, dtype: float64
# timestamp   NaN
# Name: 1891, dtype: float64
# timestamp   NaN
# Name: 1893, dtype: float64
# timestamp   NaN
# Name: 1895, dtype: float64
# timestamp   NaN
# Name: 1897, dtype: float64
# timestamp   NaN
# Name: 1899, dtype: float64
# timestamp   NaN
# Name: 1901, dtype: float64
# timestamp   NaN
# Name: 1903, dtype: float64
# timestamp   NaN
# Name: 1905, dtype: float64
# timestamp   NaN
# Name: 1907, dtype: float64
# timestamp   NaN
# Name: 1909, dtype: float64
# timestamp   NaN
# Name: 1911, dtype: float64
# timestamp   NaN
# Name: 1913, dtype: float64
# timestamp   NaN
# Name: 1915, dtype: float64
# timestamp   NaN
# Name: 1917, dtype: float64
# timestamp   NaN
# Name: 1919, dtype: float64
# timestamp   NaN
# Name: 1921, dtype: float64
# timestamp   NaN
# Name: 1923, dtype: float64
# timestamp   NaN
# Name: 1925, dtype: float64
# timestamp   NaN
# Name: 1927, dtype: float64
# timestamp   NaN
# Name: 1929, dtype: float64
# timestamp   NaN
# Name: 1931, dtype: float64
# timestamp   NaN
# Name: 1933, dtype: float64
# timestamp   NaN
# Name: 1935, dtype: float64
# timestamp   NaN
# Name: 1937, dtype: float64
# timestamp   NaN
# Name: 1939, dtype: float64
# timestamp   NaN
# Name: 1941, dtype: float64
# timestamp   NaN
# Name: 1943, dtype: float64
# timestamp   NaN
# Name: 1945, dtype: float64
# timestamp   NaN
# Name: 1947, dtype: float64
# timestamp   NaN
# Name: 1949, dtype: float64
# timestamp   NaN
# Name: 1951, dtype: float64
# timestamp   NaN
# Name: 1953, dtype: float64
# timestamp   NaN
# Name: 1955, dtype: float64
# timestamp   NaN
# Name: 1957, dtype: float64
# timestamp   NaN
# Name: 1959, dtype: float64
# timestamp   NaN
# Name: 1961, dtype: float64
# timestamp   NaN
# Name: 1963, dtype: float64
# timestamp   NaN
# Name: 1965, dtype: float64
# timestamp   NaN
# Name: 1967, dtype: float64
# timestamp   NaN
# Name: 1969, dtype: float64
# timestamp   NaN
# Name: 1971, dtype: float64
# timestamp   NaN
# Name: 1973, dtype: float64
# timestamp   NaN
# Name: 1975, dtype: float64
# timestamp   NaN
# Name: 1977, dtype: float64
# timestamp   NaN
# Name: 1979, dtype: float64
# timestamp   NaN
# Name: 1981, dtype: float64
# timestamp   NaN
# Name: 1983, dtype: float64
# timestamp   NaN
# Name: 1985, dtype: float64
# timestamp   NaN
# Name: 1987, dtype: float64
# timestamp   NaN
# Name: 1989, dtype: float64
# timestamp   NaN
# Name: 1991, dtype: float64
# timestamp   NaN
# Name: 1993, dtype: float64
# timestamp   NaN
# Name: 1995, dtype: float64
# timestamp   NaN
# Name: 1997, dtype: float64
# timestamp   NaN
# Name: 1999, dtype: float64
# timestamp   NaN
# Name: 2001, dtype: float64
# timestamp   NaN
# Name: 2003, dtype: float64
# timestamp   NaN
# Name: 2005, dtype: float64
# timestamp   NaN
# Name: 2007, dtype: float64
# timestamp   NaN
# Name: 2009, dtype: float64
# timestamp   NaN
# Name: 2011, dtype: float64
# timestamp   NaN
# Name: 2013, dtype: float64
# timestamp   NaN
# Name: 2015, dtype: float64
# timestamp   NaN
# Name: 2017, dtype: float64
# timestamp   NaN
# Name: 2019, dtype: float64
# timestamp   NaN
# Name: 2021, dtype: float64
# timestamp   NaN
# Name: 2023, dtype: float64
# timestamp   NaN
# Name: 2025, dtype: float64
# timestamp   NaN
# Name: 2027, dtype: float64
# timestamp   NaN
# Name: 2029, dtype: float64
# timestamp   NaN
# Name: 2031, dtype: float64
# timestamp   NaN
# Name: 2033, dtype: float64
# timestamp   NaN
# Name: 2035, dtype: float64
# timestamp   NaN
# Name: 2037, dtype: float64
# timestamp   NaN
# Name: 2039, dtype: float64
# timestamp   NaN
# Name: 2041, dtype: float64
# timestamp   NaN
# Name: 2043, dtype: float64
# timestamp   NaN
# Name: 2045, dtype: float64
# timestamp   NaN
# Name: 2047, dtype: float64
# timestamp   NaN
# Name: 2049, dtype: float64
# timestamp   NaN
# Name: 2051, dtype: float64
# timestamp   NaN
# Name: 2053, dtype: float64
# timestamp   NaN
# Name: 2055, dtype: float64
# timestamp   NaN
# Name: 2057, dtype: float64
# timestamp   NaN
# Name: 2059, dtype: float64
# timestamp   NaN
# Name: 2061, dtype: float64
# timestamp   NaN
# Name: 2063, dtype: float64
# timestamp   NaN
# Name: 2065, dtype: float64
# timestamp   NaN
# Name: 2067, dtype: float64
# timestamp   NaN
# Name: 2069, dtype: float64
# timestamp   NaN
# Name: 2071, dtype: float64
# timestamp   NaN
# Name: 2073, dtype: float64
# timestamp   NaN
# Name: 2075, dtype: float64
# timestamp   NaN
# Name: 2077, dtype: float64
# timestamp   NaN
# Name: 2079, dtype: float64
# timestamp   NaN
# Name: 2081, dtype: float64
# timestamp   NaN
# Name: 2083, dtype: float64
# timestamp   NaN
# Name: 2085, dtype: float64
# timestamp   NaN
# Name: 2087, dtype: float64
# timestamp   NaN
# Name: 2089, dtype: float64
# timestamp   NaN
# Name: 2091, dtype: float64
# timestamp   NaN
# Name: 2093, dtype: float64
# timestamp   NaN
# Name: 2095, dtype: float64
# timestamp   NaN
# Name: 2097, dtype: float64
# timestamp   NaN
# Name: 2099, dtype: float64
# timestamp   NaN
# Name: 2101, dtype: float64
# timestamp   NaN
# Name: 2103, dtype: float64
# timestamp   NaN
# Name: 2105, dtype: float64
# timestamp   NaN
# Name: 2107, dtype: float64
# timestamp   NaN
# Name: 2109, dtype: float64
# timestamp   NaN
# Name: 2111, dtype: float64
# timestamp   NaN
# Name: 2113, dtype: float64
# timestamp   NaN
# Name: 2115, dtype: float64
# timestamp   NaN
# Name: 2117, dtype: float64
# timestamp   NaN
# Name: 2119, dtype: float64
# timestamp   NaN
# Name: 2121, dtype: float64
# timestamp   NaN
# Name: 2123, dtype: float64
# timestamp   NaN
# Name: 2125, dtype: float64
# timestamp   NaN
# Name: 2127, dtype: float64
# timestamp   NaN
# Name: 2129, dtype: float64
# timestamp   NaN
# Name: 2131, dtype: float64
# timestamp   NaN
# Name: 2133, dtype: float64
# timestamp   NaN
# Name: 2135, dtype: float64
# timestamp   NaN
# Name: 2137, dtype: float64
# timestamp   NaN
# Name: 2139, dtype: float64
# timestamp   NaN
# Name: 2141, dtype: float64
# timestamp   NaN
# Name: 2143, dtype: float64
# timestamp   NaN
# Name: 2145, dtype: float64
# timestamp   NaN
# Name: 2147, dtype: float64
# timestamp   NaN
# Name: 2149, dtype: float64
# timestamp   NaN
# Name: 2151, dtype: float64
# timestamp   NaN
# Name: 2153, dtype: float64
# timestamp   NaN
# Name: 2155, dtype: float64
# timestamp   NaN
# Name: 2157, dtype: float64
# timestamp   NaN
# Name: 2159, dtype: float64
# timestamp   NaN
# Name: 2161, dtype: float64
# timestamp   NaN
# Name: 2163, dtype: float64
# timestamp   NaN
# Name: 2165, dtype: float64
# timestamp   NaN
# Name: 2167, dtype: float64
# timestamp   NaN
# Name: 2169, dtype: float64
# timestamp   NaN
# Name: 2171, dtype: float64
# timestamp   NaN
# Name: 2173, dtype: float64
# timestamp   NaN
# Name: 2175, dtype: float64
# timestamp   NaN
# Name: 2177, dtype: float64
# timestamp   NaN
# Name: 2179, dtype: float64
# timestamp   NaN
# Name: 2181, dtype: float64
# timestamp   NaN
# Name: 2183, dtype: float64
# timestamp   NaN
# Name: 2185, dtype: float64
# timestamp   NaN
# Name: 2187, dtype: float64
# timestamp   NaN
# Name: 2189, dtype: float64
# timestamp   NaN
# Name: 2191, dtype: float64
# timestamp   NaN
# Name: 2193, dtype: float64
# timestamp   NaN
# Name: 2195, dtype: float64
# timestamp   NaN
# Name: 2197, dtype: float64
# timestamp   NaN
# Name: 2199, dtype: float64
# timestamp   NaN
# Name: 2201, dtype: float64
# timestamp   NaN
# Name: 2203, dtype: float64
# timestamp   NaN
# Name: 2205, dtype: float64
# timestamp   NaN
# Name: 2207, dtype: float64
# timestamp   NaN
# Name: 2209, dtype: float64
# timestamp   NaN
# Name: 2211, dtype: float64
# timestamp   NaN
# Name: 2213, dtype: float64
# timestamp   NaN
# Name: 2215, dtype: float64
# timestamp   NaN
# Name: 2217, dtype: float64
# timestamp   NaN
# Name: 2219, dtype: float64
# timestamp   NaN
# Name: 2221, dtype: float64
# timestamp   NaN
# Name: 2223, dtype: float64
# timestamp   NaN
# Name: 2225, dtype: float64
# timestamp   NaN
# Name: 2227, dtype: float64
# timestamp   NaN
# Name: 2229, dtype: float64
# timestamp   NaN
# Name: 2231, dtype: float64
# timestamp   NaN
# Name: 2233, dtype: float64
# timestamp   NaN
# Name: 2235, dtype: float64
# timestamp   NaN
# Name: 2237, dtype: float64
# timestamp   NaN
# Name: 2239, dtype: float64
# timestamp   NaN
# Name: 2241, dtype: float64
# timestamp   NaN
# Name: 2243, dtype: float64
# timestamp   NaN
# Name: 2245, dtype: float64
# timestamp   NaN
# Name: 2247, dtype: float64
# timestamp   NaN
# Name: 2249, dtype: float64
# timestamp   NaN
# Name: 2251, dtype: float64
# timestamp   NaN
# Name: 2253, dtype: float64
# timestamp   NaN
# Name: 2255, dtype: float64
# timestamp   NaN
# Name: 2257, dtype: float64
# timestamp   NaN
# Name: 2259, dtype: float64
# timestamp   NaN
# Name: 2261, dtype: float64
# timestamp   NaN
# Name: 2263, dtype: float64
# timestamp   NaN
# Name: 2265, dtype: float64
# timestamp   NaN
# Name: 2267, dtype: float64
# timestamp   NaN
# Name: 2269, dtype: float64
# timestamp   NaN
# Name: 2271, dtype: float64
# timestamp   NaN
# Name: 2273, dtype: float64
# timestamp   NaN
# Name: 2275, dtype: float64
# timestamp   NaN
# Name: 2277, dtype: float64
# timestamp   NaN
# Name: 2279, dtype: float64
# timestamp   NaN
# Name: 2281, dtype: float64
# timestamp   NaN
# Name: 2283, dtype: float64
# timestamp   NaN
# Name: 2285, dtype: float64
# timestamp   NaN
# Name: 2287, dtype: float64
# timestamp   NaN
# Name: 2289, dtype: float64
# timestamp   NaN
# Name: 2291, dtype: float64
# timestamp   NaN
# Name: 2293, dtype: float64
# timestamp   NaN
# Name: 2295, dtype: float64
# timestamp   NaN
# Name: 2297, dtype: float64
# timestamp   NaN
# Name: 2299, dtype: float64
# timestamp   NaN
# Name: 2301, dtype: float64
# timestamp   NaN
# Name: 2303, dtype: float64
# timestamp   NaN
# Name: 2305, dtype: float64
# timestamp   NaN
# Name: 2307, dtype: float64
# timestamp   NaN
# Name: 2309, dtype: float64
# timestamp   NaN
# Name: 2311, dtype: float64
# timestamp   NaN
# Name: 2313, dtype: float64
# timestamp   NaN
# Name: 2315, dtype: float64
# timestamp   NaN
# Name: 2317, dtype: float64
# timestamp   NaN
# Name: 2319, dtype: float64
# timestamp   NaN
# Name: 2321, dtype: float64
# timestamp   NaN
# Name: 2323, dtype: float64
# timestamp   NaN
# Name: 2325, dtype: float64
# timestamp   NaN
# Name: 2327, dtype: float64
# timestamp   NaN
# Name: 2329, dtype: float64
# timestamp   NaN
# Name: 2331, dtype: float64
# timestamp   NaN
# Name: 2333, dtype: float64
# timestamp   NaN
# Name: 2335, dtype: float64
# timestamp   NaN
# Name: 2337, dtype: float64
# timestamp   NaN
# Name: 2339, dtype: float64
# timestamp   NaN
# Name: 2341, dtype: float64
# timestamp   NaN
# Name: 2343, dtype: float64
# timestamp   NaN
# Name: 2345, dtype: float64
# timestamp   NaN
# Name: 2347, dtype: float64
# timestamp   NaN
# Name: 2349, dtype: float64
# timestamp   NaN
# Name: 2351, dtype: float64
# timestamp   NaN
# Name: 2353, dtype: float64
# timestamp   NaN
# Name: 2355, dtype: float64
# timestamp   NaN
# Name: 2357, dtype: float64
# timestamp   NaN
# Name: 2359, dtype: float64
# timestamp   NaN
# Name: 2361, dtype: float64
# timestamp   NaN
# Name: 2363, dtype: float64
# timestamp   NaN
# Name: 2365, dtype: float64
# timestamp   NaN
# Name: 2367, dtype: float64
# timestamp   NaN
# Name: 2369, dtype: float64
# timestamp   NaN
# Name: 2371, dtype: float64
# timestamp   NaN
# Name: 2373, dtype: float64
# timestamp   NaN
# Name: 2375, dtype: float64
# timestamp   NaN
# Name: 2377, dtype: float64
# timestamp   NaN
# Name: 2379, dtype: float64
# timestamp   NaN
# Name: 2381, dtype: float64
# timestamp   NaN
# Name: 2383, dtype: float64
# timestamp   NaN
# Name: 2385, dtype: float64
# timestamp   NaN
# Name: 2387, dtype: float64
# timestamp   NaN
# Name: 2389, dtype: float64
# timestamp   NaN
# Name: 2391, dtype: float64
# timestamp   NaN
# Name: 2393, dtype: float64
# timestamp   NaN
# Name: 2395, dtype: float64
# timestamp   NaN
# Name: 2397, dtype: float64
# timestamp   NaN
# Name: 2399, dtype: float64
# timestamp   NaN
# Name: 2401, dtype: float64
# timestamp   NaN
# Name: 2403, dtype: float64
# timestamp   NaN
# Name: 2405, dtype: float64
# timestamp   NaN
# Name: 2407, dtype: float64
# timestamp   NaN
# Name: 2409, dtype: float64
# timestamp   NaN
# Name: 2411, dtype: float64
# timestamp   NaN
# Name: 2413, dtype: float64
# timestamp   NaN
# Name: 2415, dtype: float64
# timestamp   NaN
# Name: 2417, dtype: float64
# timestamp   NaN
# Name: 2419, dtype: float64
# timestamp   NaN
# Name: 2421, dtype: float64
# timestamp   NaN
# Name: 2423, dtype: float64
# timestamp   NaN
# Name: 2425, dtype: float64
# timestamp   NaN
# Name: 2427, dtype: float64
# timestamp   NaN
# Name: 2429, dtype: float64
# timestamp   NaN
# Name: 2431, dtype: float64
# timestamp   NaN
# Name: 2433, dtype: float64
# timestamp   NaN
# Name: 2435, dtype: float64
# timestamp   NaN
# Name: 2437, dtype: float64
# timestamp   NaN
# Name: 2439, dtype: float64
# timestamp   NaN
# Name: 2441, dtype: float64
# timestamp   NaN
# Name: 2443, dtype: float64
# timestamp   NaN
# Name: 2445, dtype: float64
# timestamp   NaN
# Name: 2447, dtype: float64
# timestamp   NaN
# Name: 2449, dtype: float64
# timestamp   NaN
# Name: 2451, dtype: float64
# timestamp   NaN
# Name: 2453, dtype: float64
# timestamp   NaN
# Name: 2455, dtype: float64
# timestamp   NaN
# Name: 2457, dtype: float64
# timestamp   NaN
# Name: 2459, dtype: float64
# timestamp   NaN
# Name: 2461, dtype: float64
# timestamp   NaN
# Name: 2463, dtype: float64
# timestamp   NaN
# Name: 2465, dtype: float64
# timestamp   NaN
# Name: 2467, dtype: float64
# timestamp   NaN
# Name: 2469, dtype: float64
# timestamp   NaN
# Name: 2471, dtype: float64
# timestamp   NaN
# Name: 2473, dtype: float64
# timestamp   NaN
# Name: 2475, dtype: float64
# timestamp   NaN
# Name: 2477, dtype: float64
# timestamp   NaN
# Name: 2479, dtype: float64
# timestamp   NaN
# Name: 2481, dtype: float64
# timestamp   NaN
# Name: 2483, dtype: float64
# timestamp   NaN
# Name: 2485, dtype: float64
# timestamp   NaN
# Name: 2487, dtype: float64
# timestamp   NaN
# Name: 2489, dtype: float64
# timestamp   NaN
# Name: 2491, dtype: float64
# timestamp   NaN
# Name: 2493, dtype: float64
# timestamp   NaN
# Name: 2495, dtype: float64
# ! Dropped rows in DataFrames: (1,)
# time                                                time
# cpu                                                  cpu
# seconds                                          seconds
# ioread                                            ioread
# iowrite                                          iowrite
#                                          ...
# rpm:rpm_return_int                    rpm:rpm_return_int
# fib:fib_table_lookup                fib:fib_table_lookup
# raw_syscalls:sys_enter            raw_syscalls:sys_enter
# random:credit_entropy_bits    random:credit_entropy_bits
# timestamp                                            NaN
# Name: 546, Length: 118, dtype: object

# %%
START = df_timestamps["min_t"].min()
f'Timestamps between: {df_timestamps["min_t"].min()} and {df_timestamps["max_t"].max()}'
# Out:
# 'Timestamps between: 2023-11-03 09:13:38 and 2023-11-10 19:13:35'

# %% [markdown]
# ### Resample files

# %%
def only_return_selected_columns(df: pd.DataFrame) -> pd.DataFrame:
    selected_cols = SELECTED_FEATURES & set(df.columns)
    return df[list(selected_cols)]

def create_window_sliced_depending_on_type(df: pd.DataFrame, start_timestamp: pd.Timestamp) -> pd.DataFrame:
    data_type = DataSource.from_columns(df.columns.tolist())
    print(f"Data type: {data_type}")

    match data_type:
        case (
            DataSource.FileSystem | DataSource.KernelEvents | DataSource.ResourceUsageEvents | DataSource.ResourceUsageEvents_RP4  | DataSource.BlockInputOutputEvents
        ):
            df = only_return_selected_columns(df)
            df = feature_plotting.test_transform_all_to_numeric_columns(df.copy())
            return df.resample(TIME_WINDOW, origin=start_timestamp).mean()
        case DataSource.NetRecords:
            mean_df = net_feature_engineering.create_mean_net_df_single_label(df, time_window=TIME_WINDOW, start=start_timestamp)
            return only_return_selected_columns(mean_df)
        case DataSource.Entropy:
            if "entropy_file_count" not in SELECTED_FEATURES:
                return None
            return entropy_feature_engineering.resample_high_entropy_grouping_by_label_single_label(df, time_window=TIME_WINDOW, start=start_timestamp)
            
        case DataSource.SystemCalls:
            raise NotImplementedError("SystemCalls not implemented yet")
        

def check_if_keep_source(columns):
    data_type = DataSource.from_columns(columns.tolist())
    if data_type in [DataSource.SystemCalls, DataSource.Entropy, DataSource.NetRecords]:
        return True

    chosen_cols_from_source = data_type.value & SELECTED_FEATURES

    return any(chosen_cols_from_source)

# %%
df_mean_collection: list[pd.DataFrame] = []

for source, group_df in df.groupby(["data_source"]):
    dfs_same_source = []

    checked_source = False
    for k, row in group_df.iterrows():
        if row["filetype"] != "csv":
            print(f"Skipping {row['file_path']}")
            continue


        df_t = read_in_files.get_all_columns(row['file_path'], row["filetype"])
        if not checked_source:
            if not check_if_keep_source(df_t.columns):
                print(f"Skipping {source}")
                break
            checked_source = True

        try:
            df_mean = create_window_sliced_depending_on_type(df_t, start_timestamp=START)
        except Exception as ex:
            print(f"Problem in file {row['file_path']}")
            raise ex
        
        if df_mean is None:
            print(f"Skipping {row['file_path']}")
            continue
        
        df_mean = df_mean.copy()
        print(f"Shape: {df_mean.shape}")
        df_mean["label"] = row["label"]
        df_mean["device"] = row["device"]
        df_mean["data_source"] = row["data_source"]

        # print(f"Start and End of Index Timestamp: {df_mean.index[0]} - {df_mean.index[-1]}")
        dfs_same_source.append(df_mean)

    if len(dfs_same_source) == 0:
        print(f"Skipping {source}")
        continue
    same_df = pd.concat(dfs_same_source, axis=0)
    print(f"same_df shape: {same_df.shape}")
    df_mean_collection.append(same_df)
    # break

len(df_mean_collection)
# Out:
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# Data type: DataSource.FileSystem
# Shape: (482, 54)
# Data type: DataSource.FileSystem
# Shape: (482, 54)
# Data type: DataSource.FileSystem
# Shape: (482, 54)
# same_df shape: (4329, 57)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (483, 56)
# same_df shape: (4333, 59)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (482, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# ! Dropped rows in DataFrames: (1,)
# time                                                time
# cpu                                                  cpu
# seconds                                          seconds
# ioread                                            ioread
# iowrite                                          iowrite
#                                          ...
# rpm:rpm_return_int                    rpm:rpm_return_int
# fib:fib_table_lookup                fib:fib_table_lookup
# raw_syscalls:sys_enter            raw_syscalls:sys_enter
# random:credit_entropy_bits    random:credit_entropy_bits
# timestamp                                            NaN
# Name: 546, Length: 118, dtype: object
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (483, 73)
# same_df shape: (4332, 76)
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/1_normal/SYS_data/normal.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/2_ransomware/SYS_data/ransomware-PoC.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/3_thetick/SYS_data/thetick.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/4_bashlite/SYS_data/bashlite.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/5_httpbackdoor/SYS_data/httpbackdoor.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/6_beurk/SYS_data/beurk.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/7_backdoor/SYS_data/backdoor.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/8_bdvl/SYS_data/bdvl.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/9_xmrig/SYS_data/XMRig.zip
# Skipping ('SYS_data',)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (482, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (483, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (483, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (483, 3)
# same_df shape: (4336, 6)
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/1_normal/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/2_ransomware/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/3_thetick/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/4_bashlite/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/6_beurk/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/7_backdoor/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Xi/sensor_1/9_xmrig/ENTROPY/b8_27_eb_1a_1e_2a.csv
# Skipping ('entropy_data',)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (482, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (482, 2)
# Data type: DataSource.NetRecords
# Shape: (482, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (483, 2)
# same_df shape: (4334, 5)
# 5

# %% [markdown]
# #### Remove Dublicate Columns and Concatenate
#
# => some dont work => if Index error use merge manually

# %%
try:
    pd.concat(df_mean_collection, axis=1)
except Exception as ex:
    print(ex)

# %%
from collections import defaultdict

cols = defaultdict(int)
for dfs in df_mean_collection:
    for k in dfs.columns.tolist():
        cols[k] +=1

print("Dublicates:", [k for k, v in cols.items() if v > 1])

to_ignore = ["data_source", "label", "device"]

infos = pd.DataFrame(columns=to_ignore)

for dfs in df_mean_collection:
    for k in dfs.columns.tolist():
        if k in to_ignore:
            continue

        if cols[k] > 1:
            print(k)

            dfs.rename(columns={k: f'{k}_{dfs["data_source"].iloc[0]}'}, inplace=True)

    assert dfs["device"].nunique() == 1
    assert dfs["label"].nunique() == 9
    assert dfs["data_source"].nunique() == 1
    
    infos = pd.concat([infos,dfs[to_ignore]], axis=0)

    # for t,row in dfs.iterrows():
        # infos.append({"device": row["device"], "label": row["label"], "data_source": row["data_source"], "timestamp": t})
    
    dfs.drop(columns=to_ignore, inplace=True)
# Out:
# Dublicates: ['jbd2:jbd2_checkpoint_stats', 'writeback:writeback_dirty_inode_enqueue', 'block:block_dirty_buffer', 'jbd2:jbd2_start_commit', 'writeback:global_dirty_state', 'writeback:writeback_dirty_page', 'writeback:writeback_dirty_inode', 'block:block_bio_remap', 'writeback:sb_clear_inode_writeback', 'ext4:ext4_writepages_result', 'ext4:ext4_es_lookup_extent_enter', 'block:block_touch_buffer', 'seconds', 'ext4:ext4_releasepage', 'writeback:writeback_mark_inode_dirty', 'ext4:ext4_free_inode', 'block:block_bio_backmerge', 'filemap:mm_filemap_delete_from_page_cache', 'ext4:ext4_journal_start', 'block:block_unplug', 'filemap:mm_filemap_add_to_page_cache', 'ext4:ext4_unlink_enter', 'block:block_getrq', 'jbd2:jbd2_handle_start', 'ext4:ext4_da_update_reserve_space', 'jbd2:jbd2_handle_stats', 'label', 'device', 'data_source', 'kmem:kmem_cache_alloc', 'kmem:kfree', 'timer:timer_start', 'page-faults', 'fib:fib_table_lookup', 'task:task_newtask', 'gpio:gpio_value', 'tcp:tcp_probe', 'kmem:mm_page_alloc_zone_locked', 'kmem:mm_page_free', 'sched:sched_process_exec', 'cpu-migrations']
# jbd2:jbd2_checkpoint_stats
# writeback:writeback_dirty_inode_enqueue
# block:block_dirty_buffer
# jbd2:jbd2_start_commit
# writeback:global_dirty_state
# writeback:writeback_dirty_page
# writeback:writeback_dirty_inode
# block:block_bio_remap
# writeback:sb_clear_inode_writeback
# ext4:ext4_writepages_result
# ext4:ext4_es_lookup_extent_enter
# block:block_touch_buffer
# seconds
# ext4:ext4_releasepage
# writeback:writeback_mark_inode_dirty
# ext4:ext4_free_inode
# block:block_bio_backmerge
# filemap:mm_filemap_delete_from_page_cache
# ext4:ext4_journal_start
# block:block_unplug
# filemap:mm_filemap_add_to_page_cache
# ext4:ext4_unlink_enter
# block:block_getrq
# jbd2:jbd2_handle_start
# ext4:ext4_da_update_reserve_space
# jbd2:jbd2_handle_stats
# kmem:kmem_cache_alloc
# kmem:kfree
# writeback:writeback_dirty_inode_enqueue
# block:block_dirty_buffer
# jbd2:jbd2_start_commit
# timer:timer_start
# page-faults
# writeback:writeback_dirty_page
# writeback:writeback_dirty_inode
# fib:fib_table_lookup
# block:block_bio_remap
# task:task_newtask
# writeback:sb_clear_inode_writeback
# gpio:gpio_value
# tcp:tcp_probe
# block:block_touch_buffer
# seconds
# kmem:mm_page_alloc_zone_locked
# writeback:writeback_mark_inode_dirty
# kmem:mm_page_free
# block:block_bio_backmerge
# block:block_unplug
# sched:sched_process_exec
# filemap:mm_filemap_add_to_page_cache
# cpu-migrations
# block:block_getrq
# jbd2:jbd2_handle_start
# writeback:global_dirty_state
# jbd2:jbd2_checkpoint_stats
# kmem:kmem_cache_alloc
# kmem:kfree
# block:block_dirty_buffer
# timer:timer_start
# page-faults
# fib:fib_table_lookup
# block:block_bio_remap
# task:task_newtask
# writeback:sb_clear_inode_writeback
# ext4:ext4_writepages_result
# ext4:ext4_es_lookup_extent_enter
# gpio:gpio_value
# tcp:tcp_probe
# seconds
# block:block_touch_buffer
# kmem:mm_page_alloc_zone_locked
# ext4:ext4_releasepage
# ext4:ext4_free_inode
# kmem:mm_page_free
# filemap:mm_filemap_delete_from_page_cache
# ext4:ext4_journal_start
# sched:sched_process_exec
# filemap:mm_filemap_add_to_page_cache
# ext4:ext4_unlink_enter
# cpu-migrations
# writeback:global_dirty_state
# ext4:ext4_da_update_reserve_space
# jbd2:jbd2_handle_stats
# /tmp/ipykernel_210963/3047974697.py:28: FutureWarning: The behavior of array concatenation with empty entries is deprecated. In a future version, this will no longer exclude empty items when determining the result dtype. To retain the old behavior, exclude the empty entries before the concat operation.
#   infos = pd.concat([infos,dfs[to_ignore]], axis=0)

# %%
df_all = pd.concat(df_mean_collection[:-1], axis=1).merge(df_mean_collection[-1], how='outer', left_index=True, right_index=True)
df_all.sample(2)
# Out:
#                      ext4:ext4_mark_inode_dirty  \
# timestamp
# 2023-11-03 14:10:38                         0.0
# 2023-11-04 16:51:38                        39.5
#
#                      jbd2:jbd2_checkpoint_stats_FLS_data  \
# timestamp
# 2023-11-03 14:10:38                                  0.0
# 2023-11-04 16:51:38                                  0.5
#
#                      writeback:writeback_dirty_inode_enqueue_FLS_data  \
# timestamp
# 2023-11-03 14:10:38                                               2.0
# 2023-11-04 16:51:38                                               9.5
#
#                      ext4:ext4_discard_preallocations  \
# timestamp
# 2023-11-03 14:10:38                               0.0
# 2023-11-04 16:51:38                               8.0
#
#                      ext4:ext4_es_lookup_extent_exit  \
# timestamp
# 2023-11-03 14:10:38                            348.0
# 2023-11-04 16:51:38                            179.0
#
#                      block:block_dirty_buffer_FLS_data  \
# timestamp
# 2023-11-03 14:10:38                                0.0
# 2023-11-04 16:51:38                                9.5
#
#                      jbd2:jbd2_start_commit_FLS_data  \
# timestamp
# 2023-11-03 14:10:38                              0.0
# 2023-11-04 16:51:38                              0.5
#
#                      ext4:ext4_da_reserve_space  jbd2:jbd2_commit_logging  \
# timestamp
# 2023-11-03 14:10:38                         0.0                       0.0
# 2023-11-04 16:51:38                         4.0                       0.5
#
#                      jbd2:jbd2_end_commit  ...  \
# timestamp                                  ...
# 2023-11-03 14:10:38                   0.0  ...
# 2023-11-04 16:51:38                   0.5  ...
#
#                      writeback:global_dirty_state_RES_data  \
# timestamp
# 2023-11-03 14:10:38                                    0.0
# 2023-11-04 16:51:38                                    1.0
#
#                      ext4:ext4_da_update_reserve_space_RES_data  iowritetime  \
# timestamp
# 2023-11-03 14:10:38                                         0.0          0.0
# 2023-11-04 16:51:38                                         3.5         36.0
#
#                      jbd2:jbd2_handle_stats_RES_data  iTLB-load-misses  \
# timestamp
# 2023-11-03 14:10:38                              0.0     423630.666667
# 2023-11-04 16:51:38                             24.5     617948.000000
#
#                      write_ops   util  write_kbs  (OLD) AverageLength  \
# timestamp
# 2023-11-03 14:10:38   0.000000   0.00        0.0           530.260674
# 2023-11-04 16:51:38  10.266667  10.44        1.6           699.466667
#
#                      (OLD) VarianceLength
# timestamp
# 2023-11-03 14:10:38         413085.508473
# 2023-11-04 16:51:38         483845.303808
#
# [2 rows x 188 columns]

# %%
df_all = df_all.merge(infos["label"], how='outer', left_index=True, right_index=True)

# %%
df_all.shape, len(SELECTED_FEATURES)
# Out:
# ((21664, 189), 260)

# %%
df_all
# Out:
#                      ext4:ext4_mark_inode_dirty  \
# timestamp
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# ...                                         ...
# 2023-11-10 19:12:38                        23.5
# 2023-11-10 19:13:08                         NaN
# 2023-11-10 19:13:08                         NaN
# 2023-11-10 19:13:08                         NaN
# 2023-11-10 19:13:08                         NaN
#
#                      jbd2:jbd2_checkpoint_stats_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# ...                                                  ...
# 2023-11-10 19:12:38                                  1.0
# 2023-11-10 19:13:08                                  NaN
# 2023-11-10 19:13:08                                  NaN
# 2023-11-10 19:13:08                                  NaN
# 2023-11-10 19:13:08                                  NaN
#
#                      writeback:writeback_dirty_inode_enqueue_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# ...                                                               ...
# 2023-11-10 19:12:38                                               4.0
# 2023-11-10 19:13:08                                               NaN
# 2023-11-10 19:13:08                                               NaN
# 2023-11-10 19:13:08                                               NaN
# 2023-11-10 19:13:08                                               NaN
#
#                      ext4:ext4_discard_preallocations  \
# timestamp
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# ...                                               ...
# 2023-11-10 19:12:38                               4.0
# 2023-11-10 19:13:08                               NaN
# 2023-11-10 19:13:08                               NaN
# 2023-11-10 19:13:08                               NaN
# 2023-11-10 19:13:08                               NaN
#
#                      ext4:ext4_es_lookup_extent_exit  \
# timestamp
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# ...                                              ...
# 2023-11-10 19:12:38                            389.5
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
#
#                      block:block_dirty_buffer_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# ...                                                ...
# 2023-11-10 19:12:38                                2.5
# 2023-11-10 19:13:08                                NaN
# 2023-11-10 19:13:08                                NaN
# 2023-11-10 19:13:08                                NaN
# 2023-11-10 19:13:08                                NaN
#
#                      jbd2:jbd2_start_commit_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# ...                                              ...
# 2023-11-10 19:12:38                              0.5
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
# 2023-11-10 19:13:08                              NaN
#
#                      ext4:ext4_da_reserve_space  jbd2:jbd2_commit_logging  \
# timestamp
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# ...                                         ...                       ...
# 2023-11-10 19:12:38                         2.0                       0.5
# 2023-11-10 19:13:08                         NaN                       NaN
# 2023-11-10 19:13:08                         NaN                       NaN
# 2023-11-10 19:13:08                         NaN                       NaN
# 2023-11-10 19:13:08                         NaN                       NaN
#
#                      jbd2:jbd2_end_commit  ...  \
# timestamp                                  ...
# 2023-11-03 09:13:38                   0.5  ...
# 2023-11-03 09:13:38                   0.5  ...
# 2023-11-03 09:13:38                   0.5  ...
# 2023-11-03 09:13:38                   0.5  ...
# 2023-11-03 09:13:38                   0.5  ...
# ...                                   ...  ...
# 2023-11-10 19:12:38                   0.5  ...
# 2023-11-10 19:13:08                   NaN  ...
# 2023-11-10 19:13:08                   NaN  ...
# 2023-11-10 19:13:08                   NaN  ...
# 2023-11-10 19:13:08                   NaN  ...
#
#                      ext4:ext4_da_update_reserve_space_RES_data  iowritetime  \
# timestamp
# 2023-11-03 09:13:38                                    0.000000     0.500000
# 2023-11-03 09:13:38                                    0.000000     0.500000
# 2023-11-03 09:13:38                                    0.000000     0.500000
# 2023-11-03 09:13:38                                    0.000000     0.500000
# 2023-11-03 09:13:38                                    0.000000     0.500000
# ...                                                         ...          ...
# 2023-11-10 19:12:38                                    1.000000    27.500000
# 2023-11-10 19:13:08                                    1.333333    11.666667
# 2023-11-10 19:13:08                                    1.333333    11.666667
# 2023-11-10 19:13:08                                    1.333333    11.666667
# 2023-11-10 19:13:08                                    1.333333    11.666667
#
#                      jbd2:jbd2_handle_stats_RES_data  iTLB-load-misses  \
# timestamp
# 2023-11-03 09:13:38                         0.000000     885030.000000
# 2023-11-03 09:13:38                         0.000000     885030.000000
# 2023-11-03 09:13:38                         0.000000     885030.000000
# 2023-11-03 09:13:38                         0.000000     885030.000000
# 2023-11-03 09:13:38                         0.000000     885030.000000
# ...                                              ...               ...
# 2023-11-10 19:12:38                         7.000000     660202.500000
# 2023-11-10 19:13:08                         8.666667     744738.666667
# 2023-11-10 19:13:08                         8.666667     744738.666667
# 2023-11-10 19:13:08                         8.666667     744738.666667
# 2023-11-10 19:13:08                         8.666667     744738.666667
#
#                      write_ops      util  write_kbs  (OLD) AverageLength  \
# timestamp
# 2023-11-03 09:13:38   1.066667  5.333333   0.200000          1012.877778
# 2023-11-03 09:13:38   1.066667  5.333333   0.200000          1012.877778
# 2023-11-03 09:13:38   1.066667  5.333333   0.200000          1012.877778
# 2023-11-03 09:13:38   1.066667  5.333333   0.200000          1012.877778
# 2023-11-03 09:13:38   1.066667  5.333333   0.200000          1012.877778
# ...                        ...       ...        ...                  ...
# 2023-11-10 19:12:38   4.933333  8.533333   0.633333          1155.276569
# 2023-11-10 19:13:08   2.000000  8.223333   0.333333          1244.150943
# 2023-11-10 19:13:08   2.000000  8.223333   0.333333          1244.150943
# 2023-11-10 19:13:08   2.000000  8.223333   0.333333          1244.150943
# 2023-11-10 19:13:08   2.000000  8.223333   0.333333          1244.150943
#
#                      (OLD) VarianceLength       label
# timestamp
# 2023-11-03 09:13:38         446149.452447    1_normal
# 2023-11-03 09:13:38         446149.452447    1_normal
# 2023-11-03 09:13:38         446149.452447    1_normal
# 2023-11-03 09:13:38         446149.452447    1_normal
# 2023-11-03 09:13:38         446149.452447    1_normal
# ...                                   ...         ...
# 2023-11-10 19:12:38         359463.056745  4_bashlite
# 2023-11-10 19:13:08         297652.776999  4_bashlite
# 2023-11-10 19:13:08         297652.776999  4_bashlite
# 2023-11-10 19:13:08         297652.776999  4_bashlite
# 2023-11-10 19:13:08         297652.776999  4_bashlite
#
# [21664 rows x 189 columns]

# %% [markdown]
# # Add Sys Call Data

# %%
def read_in_preprocessed_Xi_sensor_1():
    file_path = Path('/media/<User>/DC/IS_Data_Exploration_and_Feature_Engineering_for_an_IoT_Device_Behavior_Fingerprinting_Dataset/sys_system_calls_Xi_sensor_1/merged_data.npz')
    assert file_path.exists(), 'Data not found'
    vocab_file = Path("/media/<User>/DC/IS_Data_Exploration_and_Feature_Engineering_for_an_IoT_Device_Behavior_Fingerprinting_Dataset/sys_system_calls_Xi_sensor_1/vocabulary.pkl")
    assert vocab_file.exists(), f"Vocab file at {vocab_file} does not exist."

    with np.load(file_path, allow_pickle=True) as npz:
        print(npz.files)
        X = npz['arr_0']
    print(X.shape)

    vectorizer = sys_func.create_CountVectorizer(vocab_file=vocab_file)
    cols = vectorizer.get_feature_names_out()
    cols = np.append(cols, [['timestamp'], ['label']])
    print (cols.shape)
    df = pd.DataFrame(X, columns=cols)
    # df.set_index('timestamp', inplace=True)
    read_in_files._clean_and_set_index_timestamp(df)

    label_encoder = sys_func.create_label_encoder_for_labels()
    df['label'] = label_encoder.inverse_transform(df['label'].values.astype(int))

    vectors = df.copy()
    print(vectors.shape)
    
    return vectors

sys_df = read_in_preprocessed_Xi_sensor_1()
# sys_df = only_return_selected_columns(sys_df)
# sys_df_mean = sys_df.resample(TIME_WINDOW, origin=START).mean()
# Out:
# ['arr_0']
# (10932, 151)
# Loaded set: ('accept', 'accept4', 'access', 'add_key', 'adjtimex', 'bind', 'brk', 'capget', 'capset', 'chdir', 'chmod', 'chown32', 'clock_gettime', 'clone', 'close', 'connect', 'dup', 'dup2', 'dup3', 'epoll_create1', 'epoll_ctl', 'epoll_wait', 'eventfd2', 'execve', 'exit', 'exit_group', 'faccessat', 'fadvise64_64', 'fallocate', 'fchdir', 'fchmod', 'fchmodat', 'fchown32', 'fcntl64', 'fgetxattr', 'flistxattr', 'fsetxattr', 'fstat64', 'fstatat64', 'fstatfs64', 'fsync', 'ftruncate64', 'futex', 'getcwd', 'getdents64', 'getegid32', 'geteuid32', 'getgid32', 'getgroups32', 'getpeername', 'getpgid', 'getpgrp', 'getpid', 'getppid', 'getrandom', 'getresgid32', 'getresuid32', 'getsid', 'getsockname', 'getsockopt', 'gettid', 'getuid32', 'getxattr', 'inotify_add_watch', 'inotify_rm_watch', 'ioctl', 'kcmp', 'keyctl', 'kill', 'lchown32', 'lgetxattr', 'llseek', 'lstat64', 'madvise', 'mkdir', 'mmap2', 'mount', 'mprotect', 'mremap', 'munmap', 'newselect', 'openat', 'pause', 'perf_event_open', 'pipe', 'pipe2', 'poll', 'prctl', 'pread64', 'prlimit64', 'read', 'readlink', 'readlinkat', 'recv', 'recvfrom', 'recvmsg', 'rename', 'rmdir', 'rt_sigaction', 'rt_sigprocmask', 'rt_sigreturn', 'sched_getaffinity', 'sched_setaffinity', 'sched_yield', 'semop', 'send', 'sendmmsg', 'sendmsg', 'sendto', 'set_robust_list', 'set_tid_address', 'setgid32', 'setgroups32', 'setitimer', 'setpgid', 'setregid32', 'setresgid32', 'setresuid32', 'setreuid32', 'setsid', 'setsockopt', 'setuid32', 'setxattr', 'shutdown', 'sigaltstack', 'signalfd4', 'sigreturn', 'socket', 'socketpair', 'stat64', 'statfs', 'statfs64', 'statx', 'symlink', 'sysinfo', 'tgkill', 'timerfd_create', 'timerfd_settime', 'ugetrlimit', 'umask', 'umount2', 'uname', 'unlink', 'unlinkat', 'utimensat', 'wait4', 'waitid', 'write', 'writev')
# (151,)
# (10932, 150)

# %%
sys_df.head(2)
# Out:
#                      accept   accept4    access  add_key  adjtimex      bind  \
# timestamp
# 2023-11-03 09:13:38     0.0  0.000065  0.012323      0.0       0.0  0.000178
# 2023-11-03 09:13:49     0.0  0.000452  0.018115      0.0       0.0  0.000000
#
#                           brk    capget    capset     chdir  ...  umount2  \
# timestamp                                                    ...
# 2023-11-03 09:13:38  0.013510  0.000393  0.000119  0.000039  ...      0.0
# 2023-11-03 09:13:49  0.018761  0.000962  0.000368  0.000060  ...      0.0
#
#                         uname    unlink  unlinkat  utimensat     wait4  \
# timestamp
# 2023-11-03 09:13:38  0.003081  0.000035       0.0        0.0  0.004878
# 2023-11-03 09:13:49  0.004517  0.000107       0.0        0.0  0.008140
#
#                        waitid     write    writev     label
# timestamp
# 2023-11-03 09:13:38  0.000162  0.007734  0.000040  1_normal
# 2023-11-03 09:13:49  0.000251  0.016876  0.000062  1_normal
#
# [2 rows x 150 columns]

# %%
sys_df = only_return_selected_columns(sys_df)
sys_df_mean = sys_df.resample(TIME_WINDOW, origin=START).mean()

# %%
sys_df_mean.head(2)
# Out:
#                      epoll_ctl    capget   getppid  getuid32   fstat64  \
# timestamp
# 2023-11-03 09:13:38   0.002622  0.000725  0.000329  0.008785  0.237478
# 2023-11-03 09:14:08   0.003254  0.000804  0.000415  0.008568  0.278861
#
#                      newselect  setsockopt  getsockopt  setitimer  getpgrp  \
# timestamp
# 2023-11-03 09:13:38   0.060513    0.013041    0.003451   0.000125      0.0
# 2023-11-03 09:14:08   0.057846    0.017073    0.004966   0.000129      0.0
#
#                      ...    llseek   accept4  set_robust_list      dup3  \
# timestamp            ...
# 2023-11-03 09:13:38  ...  0.329985  0.000366         0.001689  0.000049
# 2023-11-03 09:14:08  ...  0.350089  0.000461         0.002058  0.000048
#
#                          poll    waitid    setsid  prlimit64  geteuid32  \
# timestamp
# 2023-11-03 09:13:38  0.004999  0.000292  0.000081   0.000078   0.009541
# 2023-11-03 09:14:08  0.006252  0.000368  0.000113   0.000109   0.009519
#
#                        access
# timestamp
# 2023-11-03 09:13:38  0.016260
# 2023-11-03 09:14:08  0.016408
#
# [2 rows x 99 columns]

# %%
all_df1 = df_all.merge(sys_df_mean, how='outer', left_index=True, right_index=True)
print(f"all_df1 shape: {all_df1.shape}")
# Out:
# all_df1 shape: (38686, 288)

# %%
all_df1.head(4)
# Out:
#                      ext4:ext4_mark_inode_dirty  \
# timestamp
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
# 2023-11-03 09:13:38                         0.0
#
#                      jbd2:jbd2_checkpoint_stats_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
# 2023-11-03 09:13:38                                  1.0
#
#                      writeback:writeback_dirty_inode_enqueue_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
# 2023-11-03 09:13:38                                               5.5
#
#                      ext4:ext4_discard_preallocations  \
# timestamp
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
# 2023-11-03 09:13:38                               0.0
#
#                      ext4:ext4_es_lookup_extent_exit  \
# timestamp
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
# 2023-11-03 09:13:38                            267.5
#
#                      block:block_dirty_buffer_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
# 2023-11-03 09:13:38                                3.0
#
#                      jbd2:jbd2_start_commit_FLS_data  \
# timestamp
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
# 2023-11-03 09:13:38                              0.5
#
#                      ext4:ext4_da_reserve_space  jbd2:jbd2_commit_logging  \
# timestamp
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
# 2023-11-03 09:13:38                         0.0                       0.5
#
#                      jbd2:jbd2_end_commit  ...    llseek   accept4  \
# timestamp                                  ...
# 2023-11-03 09:13:38                   0.5  ...  0.329985  0.000366
# 2023-11-03 09:13:38                   0.5  ...  0.329985  0.000366
# 2023-11-03 09:13:38                   0.5  ...  0.329985  0.000366
# 2023-11-03 09:13:38                   0.5  ...  0.329985  0.000366
#
#                      set_robust_list      dup3      poll    waitid    setsid  \
# timestamp
# 2023-11-03 09:13:38         0.001689  0.000049  0.004999  0.000292  0.000081
# 2023-11-03 09:13:38         0.001689  0.000049  0.004999  0.000292  0.000081
# 2023-11-03 09:13:38         0.001689  0.000049  0.004999  0.000292  0.000081
# 2023-11-03 09:13:38         0.001689  0.000049  0.004999  0.000292  0.000081
#
#                      prlimit64  geteuid32   access
# timestamp
# 2023-11-03 09:13:38   0.000078   0.009541  0.01626
# 2023-11-03 09:13:38   0.000078   0.009541  0.01626
# 2023-11-03 09:13:38   0.000078   0.009541  0.01626
# 2023-11-03 09:13:38   0.000078   0.009541  0.01626
#
# [4 rows x 288 columns]

# %%
spath = repo_base_path / "training" / "data" / f"all_df_{TIME_WINDOW}_{DEVICE_SOURCE}.csv"

all_df1.to_csv(str(spath))
