# %% [markdown]
# # Idea
# - Get first timestamp
# - Resample Dataset to same timewindow
# - Merge?

# %%
DEVICE_SOURCE = "Jing_device1"

TIME_WINDOW = "30s"

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import pickle

# %%
sys_data_file_path = Path('/media/<User>/DC/IS_Data_Exploration_and_Feature_Engineering_for_an_IoT_Device_Behavior_Fingerprinting_Dataset/sys_system_calls_Jing_device1/merged_data.npz')
assert sys_data_file_path.exists(), 'Data not found'
vocab_file = Path("/media/<User>/DC/IS_Data_Exploration_and_Feature_Engineering_for_an_IoT_Device_Behavior_Fingerprinting_Dataset/sys_system_calls_Jing_device1/vocabulary.pkl")
assert vocab_file.exists(), f"Vocab file at {vocab_file} does not exist."

# %%
import sys
repo_base_path = Path("./../../").resolve()
assert str(repo_base_path).endswith("csg_is"), f"{repo_base_path} is not a valid path to the CSG_IS repository" 

sys.path.append(str(repo_base_path))

from py_dataset import get_all_files_df
from py_dataset import read_in_files
from py_dataset import feature_plotting
from py_dataset import feature_selection
from py_dataset import net_feature_engineering
from py_dataset import entropy_feature_engineering
from py_dataset import sys_func

from py_dataset.classes import DataSource

# %%
feature_path = repo_base_path / "data_merg" /"top_260_features.pkl"

with open(feature_path, "rb") as f:
    SELECTED_FEATURES = pickle.load(f)

# %%
data_path = Path('/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/')
assert data_path.exists()

df = get_all_files_df.main(data_path)
df.head(1)
# Out:
# txt file found, will drop /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Heqing/device1/3_thetick_4h/collections.txt
# txt file found, will drop /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Heqing/device2/1_normal/note.txt
#                                            file_path
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...
# RangeIndex(start=0, stop=622, step=1)
# csv    530
# zip     92
# Name: filetype, dtype: int64
#                                            file_path filetype  filesize_bytes
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...      csv           49419
# data_source
# SYS_data        92
# FLS_data        91
# KERN_data       91
# RES_data        91
# block_data      91
# network_data    91
# entropy_data    75
# dtype: int64
#                                            file_path filetype  filesize_bytes  \
# 0  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/...      csv           49419
#
#   researcher_name device_name     label data_source              file_name  \
# 0          Heqing     device1  1_normal  block_data  e4_5f_01_68_35_e6.csv
#
#            device
# 0  Heqing_device1

# %%
single_dev = df[df["device"] == DEVICE_SOURCE]
assert len(single_dev["device"].unique()) == 1
print(single_dev.shape)

df = single_dev
# Out:
# (63, 9)

# %% [markdown]
# ### Get First TimeStamp

# %%
def prepare_files(row, resample_time_window):
    if row["filetype"] != "csv" and row["filetype"] != "zip":
        return None

    min_t, max_t, df_t = read_in_files.get_all_timestamps(row['file_path'], row["filetype"],
                                            resample_time_window=resample_time_window)

    row["min_t"] = min_t
    row["max_t"] = max_t

    return row

rows = []
for k, row in df.iterrows():
    x = prepare_files(row, resample_time_window=None)

    rows.append(x)

df_timestamps = pd.DataFrame(rows)
# Out:
# ! Dropped rows in DataFrames: (1,)
# time                                                time
# cpu                                                  cpu
# seconds                                          seconds
# ioread                                            ioread
# iowrite                                          iowrite
#                                          ...
# rpm:rpm_return_int                    rpm:rpm_return_int
# fib:fib_table_lookup                fib:fib_table_lookup
# raw_syscalls:sys_enter            raw_syscalls:sys_enter
# random:credit_entropy_bits    random:credit_entropy_bits
# timestamp                                            NaN
# Name: 235, Length: 118, dtype: object

# %%
START = df_timestamps["min_t"].min()
f'Timestamps between: {df_timestamps["min_t"].min()} and {df_timestamps["max_t"].max()}'
# Out:
# 'Timestamps between: 2023-10-21 09:12:12 and 2023-10-31 13:43:47'

# %% [markdown]
# ### Resample files

# %%
def only_return_selected_columns(df: pd.DataFrame) -> pd.DataFrame:
    selected_cols = SELECTED_FEATURES & set(df.columns)
    return df[list(selected_cols)]

def create_window_sliced_depending_on_type(df: pd.DataFrame, start_timestamp: pd.Timestamp) -> pd.DataFrame:
    data_type = DataSource.from_columns(df.columns.tolist())
    print(f"Data type: {data_type}")

    match data_type:
        case (
            DataSource.FileSystem | DataSource.KernelEvents | DataSource.ResourceUsageEvents | DataSource.ResourceUsageEvents_RP4  | DataSource.BlockInputOutputEvents
        ):
            df = only_return_selected_columns(df)
            df = feature_plotting.test_transform_all_to_numeric_columns(df.copy())
            return df.resample(TIME_WINDOW, origin=start_timestamp).mean()
        case DataSource.NetRecords:
            mean_df = net_feature_engineering.create_mean_net_df_single_label(df, time_window=TIME_WINDOW, start=start_timestamp)
            return only_return_selected_columns(mean_df)
        case DataSource.Entropy:
            if "entropy_file_count" not in SELECTED_FEATURES:
                return None
            return entropy_feature_engineering.resample_high_entropy_grouping_by_label_single_label(df, time_window=TIME_WINDOW, start=start_timestamp)
            
        case DataSource.SystemCalls:
            raise NotImplementedError("SystemCalls not implemented yet")
        

def check_if_keep_source(columns):
    data_type = DataSource.from_columns(columns.tolist())
    if data_type in [DataSource.SystemCalls, DataSource.Entropy, DataSource.NetRecords]:
        return True

    chosen_cols_from_source = data_type.value & SELECTED_FEATURES

    return any(chosen_cols_from_source)

# %%
df_mean_collection: list[pd.DataFrame] = []

for source, group_df in df.groupby(["data_source"]):
    dfs_same_source = []

    checked_source = False
    for k, row in group_df.iterrows():
        if row["filetype"] != "csv":
            print(f"Skipping {row['file_path']}")
            continue


        df_t = read_in_files.get_all_columns(row['file_path'], row["filetype"])
        if not checked_source:
            if not check_if_keep_source(df_t.columns):
                print(f"Skipping {source}")
                break
            checked_source = True

        try:
            df_mean = create_window_sliced_depending_on_type(df_t, start_timestamp=START)
        except Exception as ex:
            print(f"Problem in file {row['file_path']}")
            raise ex
        
        if df_mean is None:
            print(f"Skipping {row['file_path']}")
            continue
        
        df_mean = df_mean.copy()
        print(f"Shape: {df_mean.shape}")
        df_mean["label"] = row["label"]
        df_mean["device"] = row["device"]
        df_mean["data_source"] = row["data_source"]

        # print(f"Start and End of Index Timestamp: {df_mean.index[0]} - {df_mean.index[-1]}")
        dfs_same_source.append(df_mean)

    if len(dfs_same_source) == 0:
        print(f"Skipping {source}")
        continue
    same_df = pd.concat(dfs_same_source, axis=0)
    print(f"same_df shape: {same_df.shape}")
    df_mean_collection.append(same_df)
    # break

len(df_mean_collection)
# Out:
# /tmp/ipykernel_98447/1828661645.py:3: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for source, group_df in df.groupby(["data_source"]):
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (482, 54)
# Data type: DataSource.FileSystem
# Shape: (480, 54)
# Data type: DataSource.FileSystem
# Shape: (483, 54)
# Data type: DataSource.FileSystem
# Shape: (481, 54)
# same_df shape: (4328, 57)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (481, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# Data type: DataSource.KernelEvents
# Shape: (482, 56)
# same_df shape: (4334, 59)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (482, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# ! Dropped rows in DataFrames: (1,)
# time                                                time
# cpu                                                  cpu
# seconds                                          seconds
# ioread                                            ioread
# iowrite                                          iowrite
#                                          ...
# rpm:rpm_return_int                    rpm:rpm_return_int
# fib:fib_table_lookup                fib:fib_table_lookup
# raw_syscalls:sys_enter            raw_syscalls:sys_enter
# random:credit_entropy_bits    random:credit_entropy_bits
# timestamp                                            NaN
# Name: 235, Length: 118, dtype: object
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (482, 73)
# Data type: DataSource.ResourceUsageEvents
# Shape: (481, 73)
# same_df shape: (4331, 76)
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/1_normal/SYS_data/normal.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/2_ransomware/SYS_data/Ransomware.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/3_thetick/SYS_data/theTick.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/4_bashlite/SYS_data/Bashlite.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/5_httpbackdoor/SYS_data/httpbackdoor.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/6_beurk/SYS_data/Beurk.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/7_backdoor/SYS_data/Backdoors.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/8_bdvl/SYS_data/Bdvl.zip
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/9_xmrig/SYS_data/XMRig.zip
# Skipping SYS_data
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (482, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (482, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (482, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (481, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (483, 3)
# Data type: DataSource.BlockInputOutputEvents
# Shape: (482, 3)
# same_df shape: (4335, 6)
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/1_normal/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/2_ransomware/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/3_thetick/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/4_bashlite/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/5_httpbackdoor/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/6_beurk/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/7_backdoor/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/8_bdvl/entropy_data/b8_27_eb_55_3d_95.csv
# Data type: DataSource.Entropy
# Skipping /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/Jing/device1/9_xmrig/entropy_data/b8_27_eb_55_3d_95.csv
# Skipping entropy_data
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (482, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (480, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (480, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (481, 2)
# Data type: DataSource.NetRecords
# Shape: (480, 2)
# same_df shape: (4327, 5)
# 5

# %% [markdown]
# #### Remove Dublicate Columns and Concatenate
#
# => some dont work => if Index error use merge manually

# %%
try:
    pd.concat(df_mean_collection, axis=1)
except Exception as ex:
    print(ex)

# %%
from collections import defaultdict

cols = defaultdict(int)
for dfs in df_mean_collection:
    for k in dfs.columns.tolist():
        cols[k] +=1

print("Dublicates:", [k for k, v in cols.items() if v > 1])

to_ignore = ["data_source", "label", "device"]

infos = pd.DataFrame(columns=to_ignore)

for dfs in df_mean_collection:
    for k in dfs.columns.tolist():
        if k in to_ignore:
            continue

        if cols[k] > 1:
            print(k)

            dfs.rename(columns={k: f'{k}_{dfs["data_source"].iloc[0]}'}, inplace=True)

    assert dfs["device"].nunique() == 1
    assert dfs["label"].nunique() == 9
    assert dfs["data_source"].nunique() == 1
    
    infos = pd.concat([infos,dfs[to_ignore]], axis=0)

    # for t,row in dfs.iterrows():
        # infos.append({"device": row["device"], "label": row["label"], "data_source": row["data_source"], "timestamp": t})
    
    dfs.drop(columns=to_ignore, inplace=True)
# Out:
# Dublicates: ['jbd2:jbd2_checkpoint_stats', 'writeback:writeback_dirty_inode_enqueue', 'writeback:writeback_mark_inode_dirty', 'block:block_touch_buffer', 'block:block_bio_remap', 'jbd2:jbd2_start_commit', 'filemap:mm_filemap_delete_from_page_cache', 'ext4:ext4_free_inode', 'writeback:writeback_dirty_page', 'jbd2:jbd2_handle_start', 'filemap:mm_filemap_add_to_page_cache', 'ext4:ext4_unlink_enter', 'block:block_dirty_buffer', 'writeback:sb_clear_inode_writeback', 'ext4:ext4_journal_start', 'jbd2:jbd2_handle_stats', 'block:block_bio_backmerge', 'block:block_getrq', 'seconds', 'writeback:writeback_dirty_inode', 'ext4:ext4_releasepage', 'writeback:global_dirty_state', 'ext4:ext4_es_lookup_extent_enter', 'block:block_unplug', 'ext4:ext4_da_update_reserve_space', 'ext4:ext4_writepages_result', 'label', 'device', 'data_source', 'gpio:gpio_value', 'kmem:kfree', 'kmem:mm_page_alloc_zone_locked', 'fib:fib_table_lookup', 'page-faults', 'kmem:mm_page_free', 'cpu-migrations', 'tcp:tcp_probe', 'kmem:kmem_cache_alloc', 'sched:sched_process_exec', 'task:task_newtask', 'timer:timer_start']
# jbd2:jbd2_checkpoint_stats
# writeback:writeback_dirty_inode_enqueue
# writeback:writeback_mark_inode_dirty
# block:block_touch_buffer
# block:block_bio_remap
# jbd2:jbd2_start_commit
# filemap:mm_filemap_delete_from_page_cache
# ext4:ext4_free_inode
# writeback:writeback_dirty_page
# jbd2:jbd2_handle_start
# filemap:mm_filemap_add_to_page_cache
# ext4:ext4_unlink_enter
# block:block_dirty_buffer
# writeback:sb_clear_inode_writeback
# ext4:ext4_journal_start
# jbd2:jbd2_handle_stats
# block:block_bio_backmerge
# block:block_getrq
# seconds
# writeback:writeback_dirty_inode
# ext4:ext4_releasepage
# writeback:global_dirty_state
# ext4:ext4_es_lookup_extent_enter
# block:block_unplug
# ext4:ext4_da_update_reserve_space
# ext4:ext4_writepages_result
# gpio:gpio_value
# writeback:writeback_dirty_inode_enqueue
# kmem:kfree
# writeback:writeback_mark_inode_dirty
# block:block_touch_buffer
# kmem:mm_page_alloc_zone_locked
# fib:fib_table_lookup
# page-faults
# block:block_bio_remap
# kmem:mm_page_free
# jbd2:jbd2_start_commit
# cpu-migrations
# tcp:tcp_probe
# writeback:writeback_dirty_page
# jbd2:jbd2_handle_start
# filemap:mm_filemap_add_to_page_cache
# kmem:kmem_cache_alloc
# block:block_dirty_buffer
# writeback:sb_clear_inode_writeback
# block:block_bio_backmerge
# block:block_getrq
# seconds
# writeback:writeback_dirty_inode
# writeback:global_dirty_state
# block:block_unplug
# sched:sched_process_exec
# task:task_newtask
# timer:timer_start
# gpio:gpio_value
# jbd2:jbd2_checkpoint_stats
# kmem:kfree
# block:block_touch_buffer
# kmem:mm_page_alloc_zone_locked
# fib:fib_table_lookup
# block:block_bio_remap
# kmem:mm_page_free
# page-faults
# filemap:mm_filemap_delete_from_page_cache
# cpu-migrations
# tcp:tcp_probe
# ext4:ext4_free_inode
# filemap:mm_filemap_add_to_page_cache
# kmem:kmem_cache_alloc
# ext4:ext4_unlink_enter
# block:block_dirty_buffer
# writeback:sb_clear_inode_writeback
# ext4:ext4_journal_start
# jbd2:jbd2_handle_stats
# seconds
# ext4:ext4_releasepage
# writeback:global_dirty_state
# sched:sched_process_exec
# ext4:ext4_es_lookup_extent_enter
# task:task_newtask
# ext4:ext4_da_update_reserve_space
# ext4:ext4_writepages_result
# timer:timer_start

# %%
new_dfs = []
for adf in df_mean_collection:
    print(adf.shape)
    adf = adf[~adf.index.duplicated(keep='first')]
    new_dfs.append(adf)
# Out:
# (4328, 54)
# (4334, 56)
# (4331, 73)
# (4335, 3)
# (4327, 2)

# %%
df_all = pd.concat(new_dfs, axis=1)
df_all.sample(2)
# Out:
#                      jbd2:jbd2_drop_transaction  \
# timestamp
# 2023-10-21 16:53:42                         0.0
# 2023-10-25 11:54:42                         0.0
#
#                      jbd2:jbd2_checkpoint_stats_FLS_data  \
# timestamp
# 2023-10-21 16:53:42                                  0.0
# 2023-10-25 11:54:42                                  0.0
#
#                      writeback:writeback_dirty_inode_enqueue_FLS_data  \
# timestamp
# 2023-10-21 16:53:42                                               2.0
# 2023-10-25 11:54:42                                               4.5
#
#                      writeback:writeback_mark_inode_dirty_FLS_data  \
# timestamp
# 2023-10-21 16:53:42                                         1330.0
# 2023-10-25 11:54:42                                         1015.0
#
#                      ext4:ext4_ext_remove_space_done  \
# timestamp
# 2023-10-21 16:53:42                              0.0
# 2023-10-25 11:54:42                              3.0
#
#                      ext4:ext4_es_lookup_extent_exit  \
# timestamp
# 2023-10-21 16:53:42                            102.0
# 2023-10-25 11:54:42                            444.5
#
#                      block:block_touch_buffer_FLS_data  \
# timestamp
# 2023-10-21 16:53:42                               61.0
# 2023-10-25 11:54:42                               93.5
#
#                      jbd2:jbd2_commit_logging  \
# timestamp
# 2023-10-21 16:53:42                       1.0
# 2023-10-25 11:54:42                       0.0
#
#                      ext4:ext4_es_insert_delayed_block  \
# timestamp
# 2023-10-21 16:53:42                                0.0
# 2023-10-25 11:54:42                                3.0
#
#                      block:block_bio_remap_FLS_data  ...  \
# timestamp                                            ...
# 2023-10-21 16:53:42                             6.0  ...
# 2023-10-25 11:54:42                             3.5  ...
#
#                      ext4:ext4_da_update_reserve_space_RES_data  \
# timestamp
# 2023-10-21 16:53:42                                         0.0
# 2023-10-25 11:54:42                                         2.0
#
#                      branch-load-misses  ext4:ext4_writepages_result_RES_data  \
# timestamp
# 2023-10-21 16:53:42        1.106612e+08                              0.333333
# 2023-10-25 11:54:42        8.684913e+07                              3.000000
#
#                      context-switches  timer:timer_start_RES_data       util  \
# timestamp
# 2023-10-21 16:53:42           10774.0                 1301.333333   9.290000
# 2023-10-25 11:54:42            7636.0                 1110.000000  11.833333
#
#                      write_kbs  write_ops  (OLD) AverageLength  \
# timestamp
# 2023-10-21 16:53:42   0.433333   3.466667           785.849645
# 2023-10-25 11:54:42   1.300000   8.000000           819.664756
#
#                      (OLD) VarianceLength
# timestamp
# 2023-10-21 16:53:42         487736.065430
# 2023-10-25 11:54:42         492195.384415
#
# [2 rows x 188 columns]

# %%
df_all = df_all.merge(infos["label"], how='outer', left_index=True, right_index=True)

# %%
df_all.shape, len(SELECTED_FEATURES)
# Out:
# ((21655, 189), 260)

# %%
df_all
# Out:
#                      jbd2:jbd2_drop_transaction  \
# 2023-10-21 09:12:12                         0.5
# 2023-10-21 09:12:12                         0.5
# 2023-10-21 09:12:12                         0.5
# 2023-10-21 09:12:12                         0.5
# 2023-10-21 09:12:12                         0.5
# ...                                         ...
# 2023-10-31 13:42:42                         2.0
# 2023-10-31 13:42:42                         2.0
# 2023-10-31 13:43:12                         1.0
# 2023-10-31 13:43:12                         1.0
# 2023-10-31 13:43:12                         1.0
#
#                      jbd2:jbd2_checkpoint_stats_FLS_data  \
# 2023-10-21 09:12:12                                  0.5
# 2023-10-21 09:12:12                                  0.5
# 2023-10-21 09:12:12                                  0.5
# 2023-10-21 09:12:12                                  0.5
# 2023-10-21 09:12:12                                  0.5
# ...                                                  ...
# 2023-10-31 13:42:42                                  2.0
# 2023-10-31 13:42:42                                  2.0
# 2023-10-31 13:43:12                                  1.0
# 2023-10-21 09:12:12  5_httpbackdoor
# 2023-10-21 09:12:12  5_httpbackdoor
# 2023-10-21 09:12:12  5_httpbackdoor
# 2023-10-21 09:12:12  5_httpbackdoor
# ...                             ...
# 2023-10-31 13:42:42          8_bdvl
# 2023-10-31 13:42:42          8_bdvl
# 2023-10-31 13:43:12          8_bdvl
# 2023-10-31 13:43:12          8_bdvl
# 2023-10-31 13:43:12          8_bdvl
#
# [21655 rows x 189 columns]

# %% [markdown]
# # Add Sys Call Data

# %%
def read_in_preprocessed_Xi_sensor_2():
    with np.load(sys_data_file_path, allow_pickle=True) as npz:
        print(npz.files)
        X = npz['arr_0']
    print(X.shape)

    vectorizer = sys_func.create_CountVectorizer(vocab_file=vocab_file)
    cols = vectorizer.get_feature_names_out()
    cols = np.append(cols, [['timestamp'], ['label']])
    print (cols.shape)
    df = pd.DataFrame(X, columns=cols)
    # df.set_index('timestamp', inplace=True)
    read_in_files._clean_and_set_index_timestamp(df)

    label_encoder = sys_func.create_label_encoder_for_labels()
    df['label'] = label_encoder.inverse_transform(df['label'].values.astype(int))

    vectors = df.copy()
    print(vectors.shape)
    
    return vectors

sys_df = read_in_preprocessed_Xi_sensor_2()
# sys_df = only_return_selected_columns(sys_df)
# sys_df_mean = sys_df.resample(TIME_WINDOW, origin=START).mean()
# Out:
# ['arr_0']
# (10651, 146)
# Loaded set: ('accept', 'accept4', 'access', 'add_key', 'adjtimex', 'bind', 'brk', 'capget', 'capset', 'chdir', 'chmod', 'chown32', 'clock_gettime', 'clone', 'close', 'connect', 'dup', 'dup2', 'dup3', 'epoll_create1', 'epoll_ctl', 'epoll_wait', 'eventfd2', 'execve', 'exit', 'exit_group', 'faccessat', 'fadvise64_64', 'fallocate', 'fchdir', 'fchmod', 'fchmodat', 'fcntl64', 'fgetxattr', 'flistxattr', 'fsetxattr', 'fstat64', 'fstatat64', 'fstatfs64', 'fsync', 'ftruncate64', 'futex', 'getcwd', 'getdents64', 'getegid32', 'geteuid32', 'getgid32', 'getgroups32', 'getpeername', 'getpgid', 'getpgrp', 'getpid', 'getppid', 'getrandom', 'getresgid32', 'getresuid32', 'getsid', 'getsockname', 'getsockopt', 'gettid', 'getuid32', 'getxattr', 'inotify_add_watch', 'ioctl', 'kcmp', 'keyctl', 'kill', 'lchown32', 'lgetxattr', 'llseek', 'lstat64', 'madvise', 'mkdir', 'mmap2', 'mount', 'mprotect', 'mremap', 'munmap', 'nan', 'newselect', 'openat', 'pause', 'perf_event_open', 'pipe', 'pipe2', 'poll', 'prctl', 'pread64', 'prlimit64', 'read', 'readlink', 'readlinkat', 'recv', 'recvfrom', 'recvmsg', 'rename', 'rmdir', 'rt_sigaction', 'rt_sigprocmask', 'rt_sigreturn', 'sched_getaffinity', 'sched_yield', 'semop', 'send', 'sendmmsg', 'sendmsg', 'sendto', 'set_robust_list', 'set_tid_address', 'setgid32', 'setgroups32', 'setitimer', 'setregid32', 'setresgid32', 'setresuid32', 'setreuid32', 'setsid', 'setsockopt', 'setuid32', 'setxattr', 'shutdown', 'sigaltstack', 'signalfd4', 'sigreturn', 'socket', 'socketpair', 'stat64', 'statfs', 'statfs64', 'symlink', 'sysinfo', 'tgkill', 'timerfd_settime', 'ugetrlimit', 'umask', 'uname', 'unlink', 'unlinkat', 'utimensat', 'utimes', 'wait4', 'waitid', 'write', 'writev')
# (146,)
# (10651, 145)

# %%
sys_df.head(2)
# Out:
#                      accept   accept4    access  add_key  adjtimex     bind  \
# timestamp
# 2023-10-21 09:12:12     0.0  0.000062  0.002348      0.0       0.0  0.00004
# 2023-10-21 09:12:23     0.0  0.000037  0.000476      0.0       0.0  0.00000
#
#                           brk    capget    capset     chdir  ...    uname  \
# timestamp                                                    ...
# 2023-10-21 09:12:12  0.002446  0.000085  0.000042  0.000007  ...  0.00064
# 2023-10-21 09:12:23  0.000662  0.000004  0.000000  0.000005  ...  0.00021
#
#                        unlink  unlinkat  utimensat  utimes     wait4  \
# timestamp
# 2023-10-21 09:12:12  0.000031       0.0        0.0     0.0  0.001151
# 2023-10-21 09:12:23  0.000008       0.0        0.0     0.0  0.000318
#
#                        waitid     write  writev           label
# timestamp
# 2023-10-21 09:12:12  0.000012  0.036758     0.0  5_httpbackdoor
# 2023-10-21 09:12:23  0.000019  0.021280     0.0  5_httpbackdoor
#
# [2 rows x 145 columns]

# %%
if sys_df["label"].unique().shape[0] != 9:
    raise Exception(f'Not all labels!!!: {sys_df["label"].unique()}')
sys_df["label"].unique()
# Out:
# array(['5_httpbackdoor', '4_bashlite', '7_backdoor', '3_thetick',
#        '1_normal', '2_ransomware', '9_xmrig', '6_beurk', '8_bdvl'],
#       dtype=object)

# %%
sys_df = only_return_selected_columns(sys_df)
sys_df_mean = sys_df.resample(TIME_WINDOW, origin=START).mean()

# %%
sys_df_mean.head(2)
# Out:
#                          dup3  getdents64  setxattr  getgid32   madvise  \
# timestamp
# 2023-10-21 09:12:12  0.000003    0.010952  0.000010  0.000795  0.000000
# 2023-10-21 09:12:42  0.000001    0.002664  0.000012  0.000449  0.000003
#
#                      statfs64      send     mkdir    getpid  timerfd_settime  \
# timestamp
# 2023-10-21 09:12:12  0.000079  0.000046  0.000030  0.014851         0.000167
# 2023-10-21 09:12:42  0.000087  0.000028  0.000033  0.013266         0.000122
#
#                      ...    mremap  epoll_wait  exit_group  setsockopt  \
# timestamp            ...
# 2023-10-21 09:12:12  ...  0.000005    0.000828    0.000519    0.000504
# 2023-10-21 09:12:42  ...  0.000008    0.000598    0.000255    0.000441
#
#                        sendto  shutdown     wait4  lgetxattr    rename  \
# timestamp
# 2023-10-21 09:12:12  0.000050  0.000036  0.000712   0.000186  0.000006
# 2023-10-21 09:12:42  0.000042  0.000031  0.000337   0.000134  0.000006
#
#                         rmdir
# timestamp
# 2023-10-21 09:12:12  0.000017
# 2023-10-21 09:12:42  0.000023
#
# [2 rows x 98 columns]

# %%
all_df1 = df_all.merge(sys_df_mean, how='outer', left_index=True, right_index=True)
print(f"all_df1 shape: {all_df1.shape}")
# Out:
# all_df1 shape: (46663, 287)

# %%
all_df1.head(4)
# Out:
#                      jbd2:jbd2_drop_transaction  \
