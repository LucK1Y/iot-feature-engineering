# %%
path = "/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/"

# %%
# !tree -a -h "/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/"
# Out:
# [4.0K]  /media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/
# ├── [   0]  Heqing
# │   ├── [4.0K]  device1
# │   │   ├── [   0]  1_normal_4h
# │   │   │   ├── [2.6G]  device1_normal_2h_50.1G.zip
# │   │   │   └── [2.6G]  device1_normal_2h_50.3G.zip
# │   │   ├── [   0]  2_ransomware_4h
# │   │   │   ├── [2.4G]  device1_ransomeware_2h_24.3G.zip
# │   │   │   └── [2.4G]  device1_ransomeware_2h_24.4G.zip
# │   │   ├── [   0]  3_thetick_4h
# │   │   │   ├── [1.3G]  device1_thetick_1h_23.4G.zip
# │   │   │   ├── [1.3G]  device1_thetick_1h_24.7G.zip
# │   │   │   └── [2.6G]  device1_thetick_2h_47.3GB.zip
# │   │   ├── [   0]  4_bashlite
# │   │   │   ├── [2.3G]  device1_bashlite_2h_41_2G.zip
# │   │   │   └── [2.5G]  device1_bashlite_2h_46G.zip
# │   │   ├── [   0]  5_httpbackdoor
# │   │   │   ├── [2.6G]  device1_httpbackdoor_2h_47G.zip
# │   │   │   └── [2.7G]  device1_httpbackdoor_2h_49_2G.zip
# │   │   ├── [   0]  6_beurk
# ...

# %%
# !tree -a -h -J "/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/"
# Out:
# [
#   {"type":"directory","name":"/media/<User>/DC/MAP_CreationOfNewDatasetsForDFL/code&data/0_raw_collected_data/","size":"4.0K","contents":[
#     {"type":"directory","name":"Heqing","size":"0","contents":[
#       {"type":"directory","name":"device1","size":"4.0K","contents":[
#         {"type":"directory","name":"1_normal_4h","size":"0","contents":[
#           {"type":"file","name":"device1_normal_2h_50.1G.zip","size":"2.6G"},
#           {"type":"file","name":"device1_normal_2h_50.3G.zip","size":"2.6G"}
#       ]},
#         {"type":"directory","name":"2_ransomware_4h","size":"0","contents":[
#           {"type":"file","name":"device1_ransomeware_2h_24.3G.zip","size":"2.4G"},
#           {"type":"file","name":"device1_ransomeware_2h_24.4G.zip","size":"2.4G"}
#       ]},
#         {"type":"directory","name":"3_thetick_4h","size":"0","contents":[
#           {"type":"file","name":"device1_thetick_1h_23.4G.zip","size":"1.3G"},
# ...
