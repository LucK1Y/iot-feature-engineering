# %% [markdown]
# # Idea
#
# Read all the csv files containing the features + their importance score
#
# Select the top feature and store them somewhere

# %%
from pathlib import Path

import numpy as np
import pandas as pd

import sys
repo_base_path = Path("./../").resolve()

output_dir = repo_base_path / "feature_selection" / "result"

assert str(repo_base_path).endswith("csg_is"), f"{repo_base_path} is not a valid path to the CSG_IS repository" 

sys.path.append(str(repo_base_path))

from py_dataset import get_all_files_df
from py_dataset import read_in_files
from py_dataset import feature_plotting
from py_dataset import feature_selection

# %%
files = list(output_dir.glob("*.csv"))
files
# Out:
# [PosixPath('/home/<User>/repos/csg_is/feature_selection/result/network_datax960s_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/network_datax40s_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/block_data_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/RES_data_Heqing_device2_featurescores_ROBUST.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/SYS_dataSystemVersion.old-bow_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/block_data_Heqing_device2_featurescores_ROBUST.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/KERN_data_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/SYS_dataSystemVersion.TWOxGRAM_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/RES_data_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/FLS_data_Heqing_device2_featurescores_ROBUST.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/entropy_data_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/SYS_dataSystemVersion.old-bow_Heqing_device2_featurescores_ROBUST.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/SYS_dataSystemVersion.OLDxBOWxWithoutMinMax_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/FLS_data_Heqing_device2_featurescores.csv'),
#  PosixPath('/home/<User>/repos/csg_is/feature_selection/result/KERN_data_Heqing_device2_featurescores_ROBUST.csv')]

# %%
import os

dfs = []
for file in files:
    infos = file.stem.split("_")

    df = pd.read_csv(str(file))
    df["data_source"] = "_".join(infos[0:2])
    df["device"] = "_".join(infos[2:4])
    df["is_robust"] = True if len(infos) > 5 and infos[5] == "ROBUST" else False

    dfs.append(df)

df = pd.concat(dfs)
df
# Out:
#           chi2   f_classif  mutual_info_classif  \
# 0     0.024650    0.390793             0.018838
# 1     0.000563    0.008145             0.110309
# 2     0.015181    0.553157             0.072971
# 3     0.014969    0.518494             0.000000
# 4     0.005461    0.251820             0.007398
# ..         ...         ...                  ...
# 202  51.176344  380.283392             0.045646
# 203   0.000370    0.012030             0.000000
# 204  30.086652   68.701713             0.008235
# 205  30.259659   69.065660             0.008695
# 206   1.120728   14.021134             0.008492
#
#                                   feature      label        data_source  \
# 0                       (OLD) PacketCount   1_normal  network_datax960s
# 1                       (OLD) TotalLength   1_normal  network_datax960s
# 2                     (OLD) AverageLength   1_normal  network_datax960s
# 3                      (OLD) MedianLength   1_normal  network_datax960s
# 4                         (OLD) MinLength   1_normal  network_datax960s
# ..                                    ...        ...                ...
# 202        writeback:writeback_dirty_page  3_thetick          KERN_data
# 203  writeback:writeback_mark_inode_dirty  3_thetick          KERN_data
# 204      writeback:writeback_single_inode  3_thetick          KERN_data
# 205       writeback:writeback_write_inode  3_thetick          KERN_data
# 206         writeback:writeback_written\n  3_thetick          KERN_data
#
#              device  is_robust
# 0    Heqing_device2      False
# 1    Heqing_device2      False
# 2    Heqing_device2      False
# 3    Heqing_device2      False
# 4    Heqing_device2      False
# ..              ...        ...
# 202  Heqing_device2       True
# 203  Heqing_device2       True
# 204  Heqing_device2       True
# 205  Heqing_device2       True
# 206  Heqing_device2       True
#
# [49258 rows x 8 columns]

# %%
print(df["device"].unique())
df = df[~df["is_robust"]]

df = df.drop(columns=["is_robust", "device"])

df
# Out:
# ['Heqing_device2']
#           chi2  f_classif  mutual_info_classif  \
# 0     0.024650   0.390793             0.018838
# 1     0.000563   0.008145             0.110309
# 2     0.015181   0.553157             0.072971
# 3     0.014969   0.518494             0.000000
# 4     0.005461   0.251820             0.007398
# ...        ...        ...                  ...
# 1039  8.739920  72.296545             0.024950
# 1040  2.654147  29.874139             0.012072
# 1041  8.899036  69.082521             0.028515
# 1042  8.899036  69.082521             0.029355
# 1043  2.512259  28.180825             0.011550
#
#                                      feature     label        data_source
# 0                          (OLD) PacketCount  1_normal  network_datax960s
# 1                          (OLD) TotalLength  1_normal  network_datax960s
# 2                        (OLD) AverageLength  1_normal  network_datax960s
# 3                         (OLD) MedianLength  1_normal  network_datax960s
# 4                            (OLD) MinLength  1_normal  network_datax960s
# ...                                      ...       ...                ...
# 1039  writeback:writeback_single_inode_start   9_xmrig           FLS_data
# 1040               writeback:writeback_start   9_xmrig           FLS_data
# 1041         writeback:writeback_write_inode   9_xmrig           FLS_data
# 1042   writeback:writeback_write_inode_start   9_xmrig           FLS_data
# 1043           writeback:writeback_written\n   9_xmrig           FLS_data
#
# [47916 rows x 6 columns]

# %% [markdown]
# # Remove unnecessary Sys and network with 960s

# %%
sys_bow_features = df[df["data_source"]=="SYS_dataSystemVersion.old-bow"]["feature"].unique()

mask = (df["data_source"]=="SYS_dataSystemVersion.TWOxGRAM") & (df["feature"].isin(sys_bow_features))
len(sys_bow_features), mask.value_counts()

df = df[~mask]

# %%
mask = df["data_source"]=="SYS_dataSystemVersion.OLDxBOWxWithoutMinMax"
print(df[mask].shape)

df = df[~mask]
# Out:
# (1431, 6)

# %%
df = df[~((df["data_source"]=="SYS_dataSystemVersion.TWOxGRAM") | (df["data_source"]=="network_datax960s"))]

# %% [markdown]
# # Store Away top k

# %%
top_k = 200

for label, group in df.groupby("label"):
    largest_chi = group.nlargest(top_k, columns=["chi2"])#[["chi2", "feature", "data_source"]]
    largest_f_classif = group.nlargest(top_k, columns=["f_classif"])#[["f_classif", "feature", "data_source"]]
    largest_mutual_info_classif = group.nlargest(top_k, columns=["mutual_info_classif"])#[["mutual_info_classif", "feature", "data_source"]]

    # largest_chi["score_type"] = "chi2"
    # largest_chi.rename(columns={"chi2": "score"}, inplace=True)

    # largest_f_classif["score_type"] = "f_classif"
    # largest_f_classif.rename(columns={"f_classif": "score"}, inplace=True)

    # largest_mutual_info_classif["score_type"] = "mutual_info_classif"
    # largest_mutual_info_classif.rename(columns={"mutual_info_classif": "score"}, inplace=True)

    largest = pd.concat([largest_chi, largest_f_classif, largest_mutual_info_classif])

# %%
largest.shape
# Out:
# (600, 6)

# %%
largest_set = set(largest["feature"].to_list())
largest_set, len(largest_set)
# Out:
# ({'(OLD) AverageLength',
#   '(OLD) VarianceLength',
#   'L1-dcache-load-misses',
#   'L1-dcache-loads',
#   'L1-dcache-stores',
#   'L1-icache-load-misses',
#   'L1-icache-loads',
#   'LLC-load-misses',
#   'LLC-loads',
#   'LLC-store-misses',
#   'LLC-stores',
#   'accept4',
#   'access',
#   'armv7_cortex_a15/br_mis_pred/',
#   'armv7_cortex_a15/br_pred/',
#   'armv7_cortex_a15/bus_cycles/',
#   'armv7_cortex_a15/bus_cycles/.1',
#   'armv7_cortex_a15/cpu_cycles/',
#   'armv7_cortex_a15/exc_return/',
#   'armv7_cortex_a15/exc_taken/',
#   'armv7_cortex_a15/l1d_cache/',
#   'armv7_cortex_a15/l1d_cache_refill/',
#   'armv7_cortex_a15/l1d_tlb_refill/',
#   'armv7_cortex_a15/l1i_cache/',
#   'armv7_cortex_a15/l1i_cache_refill/',
#   'armv7_cortex_a15/l1i_tlb_refill/',
#   'armv7_cortex_a15/l2d_cache/',
#   'armv7_cortex_a15/l2d_cache_wb/',
#   'armv7_cortex_a15/mem_access/',
#   'block:block_bio_backmerge',
#   'block:block_bio_queue',
#   'block:block_bio_remap',
#   'block:block_dirty_buffer',
#   'block:block_getrq',
#   'block:block_rq_complete',
#   'block:block_rq_insert',
#   'block:block_rq_issue',
#   'block:block_touch_buffer',
#   'block:block_unplug',
#   'branch-instructions',
#   'branch-load-misses',
#   'branch-loads',
#   'branch-misses',
#   'brk',
#   'bus-cycles',
#   'cache-misses',
#   'cache-references',
#   'capget',
#   'capset',
#   'chdir',
#   'chown32',
#   'clock_gettime',
#   'clone',
#   'close',
#   'connect',
#   'context-switches',
#   'cpu',
#   'cpu-cycles',
#   'cpu-migrations',
#   'cs',
#   'dTLB-load-misses',
#   'dTLB-store-misses',
#   'dup',
#   'dup2',
#   'dup3',
#   'epoll_create1',
#   'epoll_ctl',
#   'epoll_wait',
#   'execve',
#   'exit',
#   'exit_group',
#   'ext4:ext4_begin_ordered_truncate',
#   'ext4:ext4_da_reserve_space',
#   'ext4:ext4_da_update_reserve_space',
#   'ext4:ext4_da_write_begin',
#   'ext4:ext4_da_write_end',
#   'ext4:ext4_discard_preallocations',
#   'ext4:ext4_es_insert_delayed_block',
#   'ext4:ext4_es_lookup_extent_enter',
#   'ext4:ext4_es_lookup_extent_exit',
#   'ext4:ext4_ext_remove_space',
#   'ext4:ext4_ext_remove_space_done',
#   'ext4:ext4_ext_rm_leaf',
#   'ext4:ext4_free_inode',
#   'ext4:ext4_invalidatepage',
#   'ext4:ext4_journal_start',
#   'ext4:ext4_mark_inode_dirty',
#   'ext4:ext4_readpage',
#   'ext4:ext4_releasepage',
#   'ext4:ext4_truncate_enter',
#   'ext4:ext4_truncate_exit',
#   'ext4:ext4_unlink_enter',
#   'ext4:ext4_unlink_exit',
#   'ext4:ext4_writepages_result',
#   'faccessat',
#   'fchmod',
#   'fib:fib_table_lookup',
#   'filemap:mm_filemap_add_to_page_cache',
#   'filemap:mm_filemap_delete_from_page_cache',
#   'fstat64',
#   'fstatat64',
#   'ftruncate64',
#   'getcwd',
#   'getdents64',
#   'getegid32',
#   'geteuid32',
#   'getgid32',
#   'getpeername',
#   'getpgrp',
#   'getpid',
#   'getppid',
#   'getrandom',
#   'getsockname',
#   'getsockopt',
#   'gettimeofday',
#   'getuid32',
#   'getxattr',
#   'gpio:gpio_value',
#   'iTLB-load-misses',
#   'inotify_add_watch',
#   'instructions',
#   'iobusytime',
#   'ioctl',
#   'iowrite',
#   'iowritebytes',
#   'iowritetime',
#   'irq:irq_handler_entry',
#   'irq:softirq_entry',
#   'irq:softirq_exit',
#   'jbd2:jbd2_checkpoint_stats',
#   'jbd2:jbd2_commit_flushing',
#   'jbd2:jbd2_commit_locking',
#   'jbd2:jbd2_commit_logging',
#   'jbd2:jbd2_drop_transaction',
#   'jbd2:jbd2_end_commit',
#   'jbd2:jbd2_handle_extend',
#   'jbd2:jbd2_handle_start',
#   'jbd2:jbd2_handle_stats',
#   'jbd2:jbd2_run_stats',
#   'jbd2:jbd2_start_commit',
#   'kcmp',
#   'kmem:kfree',
#   'kmem:kmalloc',
#   'kmem:kmem_cache_alloc',
#   'kmem:kmem_cache_free',
#   'kmem:mm_page_alloc',
#   'kmem:mm_page_alloc_zone_locked',
#   'kmem:mm_page_free',
#   'kmem:mm_page_pcpu_drain',
#   'lgetxattr',
#   'llseek',
#   'lstat64',
#   'madvise',
#   'memory',
#   'minor-faults',
#   'mkdir',
#   'mmap2',
#   'mprotect',
#   'mremap',
#   'munmap',
#   'napi:napi_poll',
#   'net:net_dev_queue',
#   'net:net_dev_xmit',
#   'net_in',
#   'net_out',
#   'newselect',
#   'open',
#   'openat',
#   'page-faults',
#   'pagemap:mm_lru_activate',
#   'pagemap:mm_lru_insertion',
#   'pause',
#   'pipe',
#   'pipe2',
#   'pkt_in',
#   'pkt_out',
#   'poll',
#   'prctl',
#   'preemptirq:irq_enable',
#   'prlimit64',
#   'qdisc:qdisc_dequeue',
#   'qdisc:qdisc_dequeue.1',
#   'random:get_random_bytes',
#   'random:urandom_read',
#   'read',
#   'readlink',
#   'readlinkat',
#   'recv',
#   'recvfrom',
#   'rename',
#   'rmdir',
#   'rpm:rpm_return_int',
#   'rt_sigaction',
#   'rt_sigprocmask',
#   'sched:sched_process_exec',
#   'sched:sched_process_free',
#   'sched:sched_process_wait',
#   'sched:sched_stat_runtime',
#   'sched:sched_switch',
#   'sched:sched_wakeup',
#   'sched:sched_waking',
#   'sched_yield',
#   'seconds',
#   'send',
#   'sendmsg',
#   'sendto',
#   'set_robust_list',
#   'set_tid_address',
#   'setgroups32',
#   'setitimer',
#   'setresgid32',
#   'setresuid32',
#   'setsid',
#   'setsockopt',
#   'setuid32',
#   'setxattr',
#   'shutdown',
#   'sigaltstack',
#   'signal:signal_deliver',
#   'signal:signal_generate',
#   'sigreturn',
#   'skb:consume_skb',
#   'skb:consume_skb.1',
#   'skb:kfree_skb',
#   'skb:kfree_skb.1',
#   'skb:skb_copy_datagram_iovec',
#   'socket',
#   'stat64',
#   'statfs64',
#   'sysinfo',
#   'task:task_newtask',
#   'tcp:tcp_probe',
#   'timer:hrtimer_start',
#   'timer:tick_stop',
#   'timer:timer_cancel',
#   'timer:timer_init',
#   'timer:timer_start',
#   'timerfd_create',
#   'timerfd_settime',
#   'ugetrlimit',
#   'umask',
#   'uname',
#   'unlink',
#   'util',
#   'wait4',
#   'waitid',
#   'workqueue:workqueue_activate_work',
#   'workqueue:workqueue_execute_start',
#   'write',
#   'write_kbs',
#   'write_merge',
#   'write_ops',
#   'writeback:global_dirty_state',
#   'writeback:sb_clear_inode_writeback',
#   'writeback:writeback_dirty_inode',
#   'writeback:writeback_dirty_inode_enqueue',
#   'writeback:writeback_dirty_inode_start',
#   'writeback:writeback_dirty_page',
#   'writeback:writeback_mark_inode_dirty',
#   'writev'},
#  260)

# %%
import pickle

path = repo_base_path / "data_merg" / f"top_{len(largest_set)}_features.pkl"

with open(path, "wb") as f:
    pickle.dump(largest_set, f)
